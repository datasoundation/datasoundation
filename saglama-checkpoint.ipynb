# %% [markdown]
# # Music Producers Gender Distribution

# %% [markdown]
# ## Querying a SPARQL endpoint with SPARQLWrapper library

# %% [markdown]
# We are using the SPARQLWrapper library to execute a SPARQL query against the Wikidata SPARQL endpoint. The query aims to count the number of distinct people who have a profession of record producer and group the result by gender. First we import the necessary libraries, SPARQLWrapper and pprint. The variable wikidata_endpoint is set to the Wikidata SPARQL endpoint URL, which is used as the target of the SPARQL query. The variable my_SPARQL_query contains the SPARQL query that will be executed from the Wikidata SPARQL endpoint. The query filters to only include people, gets their gender and profession, and sets the language of the labels to English. The results are then grouped by gender, sorted by the number of individuals in each group, and returned in a JSON format. We used the pp library to print the results in a readable format.

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pprint as pp

wikidata_endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql"


my_SPARQL_query = """
SELECT DISTINCT ?gendername (COUNT(?person) AS ?totResult)
WHERE
{
       # ?person wdt:P31 wd:Q5 ;
              wdt:P21 ?gender ;
              wdt:P106/wdt:P279* wd:Q183945. 
       # ?gender rdfs:label ?gendername .
        SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" . }
       FILTER (lang(?gendername) = 'en')
}
GROUP BY ?gendername
ORDER BY DESC(?totResult)
"""

sparql_wd = SPARQLWrapper(wikidata_endpoint)
sparql_wd.setQuery(my_SPARQL_query)
sparql_wd.setReturnFormat(JSON)
totalResults = sparql_wd.query().convert()

# %% [markdown]
# Then we are looping through the bindings of the totalResults variable. For each result in the bindings, it extracts the gender and total count from the result, and stores them in the musicProducers dictionary. The gender is used as the key and the total count as the value. It also appends the total count to the totNumber list. Then it prints out the number of music producers for each gender. After the loop, it calculates the total number of all music producers by summing up the numbers in the totNumber list, and adds this value to the musicProducers dictionary with key 'totResult'. The final step is to create a new dictionary called final_json and add the musicProducers dictionary as the value for the "producers" key. The final_json is printed using the pprint library.

# %%
musicProducers = dict()  #producer
totNumber = list()   #totNumber

for result in totalResults["results"]["bindings"]:
    gender = result["gendername"]["value"]
    total = result["totResult"]["value"]
    musicProducers[gender] = total
    totNumber.append(int(total))
    print("Number of " + gender + " music producers is " + total)
    
allProducers = sum(totNumber)
musicProducers['totResult'] = str(allProducers)
print("Number of all music producers is " + str(allProducers))

final_json = dict()
final_json["producers"] = musicProducers
pp.pprint(musicProducers)
# Out:
# Number of male music producers is 14995
# Number of female music producers is 962
# Number of trans woman music producers is 9
# Number of non-binary music producers is 7
# Number of genderfluid music producers is 1
# Number of trans man music producers is 1
# Number of intersex music producers is 1
# Number of genderqueer music producers is 1
# Number of all music producers is 15977
# {'female': '962',
#  'genderfluid': '1',
#  'genderqueer': '1',
#  'intersex': '1',
#  'male': '14995',
#  'non-binary': '7',
#  'totResult': '15977',
#  'trans man': '1',
#  'trans woman': '9'}

# %%
import json

with open("musicProducers.json", "w") as outfile:
    json.dump(final_json, outfile)

# %% [markdown]
# # IT DOESNT MAKE SENSE BECAUSE IT DISPLAYS ONLY MALE AND FEMALE
#
# We used the bokeh library to create a bar chart of the gender distribution of music producers. First we import the necessary modules from bokeh, including output_notebook() which is used to display the chart in a Jupyter notebook. A list of genders is defined, which will be used as the x-axis of the chart. The code then uses the musicProducers dictionary to get the number of music producers for each gender and assigns them to variables totalm, totalf, totaltw, totalnb, totaltm, totali, totalgf and totalgq. A color_list variable is also defined, it contains 8 hex color codes that will be used to color the bars of the chart respectively.
#
# A new figure object is created, with the x_range set to the genders list, the plot_height set to 500, and the title set to "gender distribution". The vbar() method is then called on the figure object to create the bars, with x set to the genders list, top set to the list of number of music producers for each gender, color set to the color_list, and the width set to 0.6.
#
# The grid lines color is set to None, and the y_range start is set to 0. The chart is then displayed using the show() function.

# %%
import numpy as np
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
output_notebook()


genders = ['male','female','trans woman','non-binary','trans man','intersex','genderfluid','genderqueer']

totalm = int(musicProducers.get('male'))
totalf = int(musicProducers.get('female'))
totaltw = int(musicProducers.get('trans woman'))
totalnb = int(musicProducers.get('non-binary'))
totaltm = int(musicProducers.get('trans man'))
totali = int(musicProducers.get('intersex'))
totalgf = int(musicProducers.get('genderfluid'))
totalgq = int(musicProducers.get('genderqueer'))


color_list = ["#7dbf6f","#099bf7", "#8c3b6e", "#ade6dc", "#aba77d", "#708847", "#f1b82b", "#d74e81"]

p = figure(x_range=genders, plot_height=500, title="gender distribution")
p.vbar(x=genders, top=[totalm, totalf, totaltw, totalnb, totaltm, totali, totalgf, totalgq], color=color_list, width=0.6)

p.xgrid.grid_line_color = None
p.y_range.start = 0

show(p)
# Out:
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1101">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="d9f17886-c3c7-48a0-84a6-1e3c1c3bd395" data-root-id="1102"></div>

# %% [markdown]
# We are using the wordcloud library to create a word cloud visualization. We first create a list of word, which in this case is a string of text containing the words 'male', 'female', 'trans woman', 'non-binary', 'trans man', 'intersex', 'genderfluid' and 'genderqueer' separated by space. We then create an object of the WordCloud class and set the width, height, and margin of the image. We call the generate() method on the object and pass in the text, this will generate the word cloud based on the text. We use the plt.imshow() method to display the generated image, with interpolation set to bilinear. We use plt.axis("off") to remove the axis from the graph and plt.margins(x=0, y=0) to set the margins to 0. Finally, we use plt.show() to display the word cloud.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Create a list of word
# text=("Python Python Python Matplotlib")
text = ('male female trans woman non-binary trans man intersex genderfluid genderqueer')

# Create the wordcloud object
wordcloud = WordCloud(width=800, height=600, margin=20).generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()

# %% [markdown]
# ## Nationality of female producers

# %% [markdown]
# # Will be fixed
#
# We are using the SPARQLWrapper library to execute a SPARQL query against the Wikidata SPARQL endpoint. The query aims to count the number of distinct female people who have a profession of record producer and group the result by country. We set the endpoint URL for the Wikidata SPARQL endpoint in the variable wikidata_endpoint. The variable top_nation contains the SPARQL query that will be executed from the Wikidata SPARQL endpoint. We use ?human wdt:P106 wd:Q183945 and wdt:P21 wd:Q6581072 to filter the results to only include female people with the profession of record producer . We use wdt:P27 ?country to get the country of the person. We use SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". } to set the language of the labels to be English. The query uses GROUP BY ?countryLabel to group the results by country. The query uses ORDER BY DESC(?total) to sort the results in descending order of the number of people in each country. We set the query to sparql_wd using the setQuery() method. The format of the returned result is set to JSON using the setReturnFormat() method. The query is executed and the results are returned in a JSON format and assigned to the variable top_nation_result.

# %%
wikidata_endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql"

top_nation = '''
SELECT ?countryLabel (COUNT(?human) AS ?total)

WHERE 
{ 
  # ?human wdt:P21 wd:Q6581072; 
         wdt:P106 wd:Q183945; 
         wdt:P27 ?country
  SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}
GROUP BY ?countryLabel 
ORDER BY DESC(?total)
LIMIT 10
'''

# set the endpoint 
sparql_wd = SPARQLWrapper(wikidata_endpoint)
# set the query
sparql_wd.setQuery(top_nation)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
top_nation_result = sparql_wd.query().convert()

# %% [markdown]
# # Will be fixed
#
# This code is creating a CSV file and then using that CSV file to create a dataframe and plot a bar chart.
#
# The first section of code is creating a CSV file named 'countryProducers.csv' with the column names 'Country' and 'Number'. It is then using a for loop to iterate through a list called "top_nation_result" and writing the values of "countryLabel" and "total" to the CSV file, with each iteration of the loop creating a new row in the file.
#
# The next section is using the pandas library to read the CSV file and create a dataframe named 'df'. It then prints the first 10 rows of the dataframe using the .head() function.
#
# Then the code is calculating the sum of the 'Number' column in the dataframe and using that value to calculate the percentage of each value in the 'Number' column and then creating a new column 'Percentage' in the dataframe and storing the calculated percentage in it.
#
# After that, it is rounding the percentage values to 2 decimal places and printing the first 10 rows of the dataframe again.
#
# Finally, the code is using the Matplotlib library to plot a bar chart of the dataframe, with the x-axis being the 'Country' column and the y-axis being the 'Percentage' column. It's also adding title, x and y labels to the chart and then showing the plot.

# %%
#create CSV
import pandas as pd
import csv

with open('countryProducers.csv', mode='w') as my_file:
    my_writer = csv.writer(my_file, delimiter=',', quoting=csv.QUOTE_ALL)
    # write the column names
    my_writer.writerow(['Country', 'Number'])
    for result in top_nation_result ["results"]["bindings"]:
        my_writer.writerow([result["countryLabel"]["value"], result["total"]["value"].strip()])
        
# parse the csv into a dataframe
df = pd.read_csv("countryProducers.csv")


# print the first 10 rows
df.head(10)

sum = df['Number'].sum()

percentage = (df['Number']/sum)*100

    
df['Percentage']= percentage

df['Percentage']= df['Percentage'].round(decimals = 2)

#print the first 20 rows
df.head(10)


import matplotlib.pyplot as plt

# Bar chart visualization
df.plot(x='Country', y='Percentage', kind='bar')

# Adding title and labels
plt.title('Country-wise Percentage Distribution')
plt.xlabel('Country')
plt.ylabel('Percentage')

# Show the plot
plt.show()

# %% [markdown]
# # Will be fixed
#
# This code is using the Matplotlib library to create a pie chart that represents the percentage of producers by country.
#
# The first line is importing the Matplotlib library and renaming it as 'plt' for easier usage in the rest of the code.
#
# The next line is using the 'plt.pie' function to create a pie chart. The first argument passed to the function is the 'Percentage' column of the 'df' dataframe, which represents the values of the pie chart. The 'labels' argument is set to the 'Country' column of the 'df' dataframe, which represents the labels for each slice of the pie chart. The 'autopct' argument is set to '%1.1f%%', which is used to format the percentage values that are displayed on the chart.
#
# The next line is adding a title to the chart using the 'plt.title' function, with the title being 'Percentage of Producers by Country'.
#
# Finally, the code is using the 'plt.show' function to display the chart.

# %%
import matplotlib.pyplot as plt

# create a pie chart
plt.pie(df['Percentage'], labels=df['Country'], autopct='%1.1f%%')

# add title
plt.title('Percentage of Producers by Country')

# show the chart
plt.show()

# %%
import matplotlib.pyplot as plt

# create a line chart
df.plot(kind='line', x='Country', y='Percentage', legend=False)

# add labels and title
plt.xlabel('Country')
plt.ylabel('Percentage')
plt.title('Percentage of Producers by Country')

# show the chart
plt.show()

# %%
import matplotlib.pyplot as plt

# create a scatter plot
plt.scatter(df['Country'], df['Number'])

# add labels and title
plt.xlabel('Country')
plt.ylabel('Number of Producers')
plt.title('Number of Producers by Country')

# show the chart
plt.show()

# %% [markdown]
# PREFIX wd: <http://www.wikidata.org/entity/>
# PREFIX wdt: <http://www.wikidata.org/prop/direct/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# SELECT DISTINCT ?gendername (COUNT(?person) AS ?totResult)
# WHERE
# {
#   ?GrammyAward wdt:P31* wd:Q41254.
#   ?person wdt:P31 wd:Q5 ;
#             wdt:P21 ?gender ;
#             wdt:P106/wdt:P31* wd:Q183945;
#             wdt:P166 ?GrammyAward.
#
#   ?gender rdfs:label ?gendername .
#   SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" . }
#   FILTER (lang(?gendername) = 'en')
# }
# GROUP BY ?gendername
# ORDER BY DESC(?totResult)

# %% [markdown]
# # Second query on songwriters

# %%
my_SPARQL_query2 = """
SELECT DISTINCT ?gendername (COUNT(?person) AS ?tResult)
WHERE
{
       # ?person wdt:P31 wd:Q5 ;
              wdt:P21 ?gender ;
              wdt:P106/wdt:P279* wd:Q753110. 
       # ?gender rdfs:label ?gendername .
        SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en" . }
       FILTER (lang(?gendername) = 'en')
}
GROUP BY ?gendername
ORDER BY DESC(?tResult)
"""

sparql_wd = SPARQLWrapper(wikidata_endpoint)
sparql_wd.setQuery(my_SPARQL_query2)
sparql_wd.setReturnFormat(JSON)
totalResults2 = sparql_wd.query().convert()

# %%
musicWriters = dict()  #writer
totNumber2 = list()   #totNumber2

for result in totalResults2["results"]["bindings"]:
    gender = result["gendername"]["value"]
    total = result["tResult"]["value"]
    musicWriters[gender] = total
    totNumber2.append(int(total))
    print("Number of " + gender + " song writers is " + total)
    
allWriters = sum(totNumber2)
musicWriters["tResult"] = str(allWriters)
print("Number of all song writers is " + str(allWriters))

final_json2 = dict()
final_json2["songWriters"] = musicWriters
pp.pprint(musicWriters)
# Out:
# Number of male song writers is 31660
# Number of female song writers is 11363
# Number of non-binary song writers is 51
# Number of trans woman song writers is 36
# Number of genderfluid song writers is 12
# Number of trans man song writers is 12
# Number of genderqueer song writers is 6
# Number of travesti song writers is 3
# Number of cisgender female song writers is 1
# Number of cisgender male song writers is 1
# Number of agender song writers is 1
# Number of intersex song writers is 1
# Number of transgender song writers is 1
# Number of all song writers is 43148
# {'agender': '1',
#  'cisgender female': '1',
#  'cisgender male': '1',
#  'female': '11363',
#  'genderfluid': '12',
#  'genderqueer': '6',
#  'intersex': '1',
#  'male': '31660',
#  'non-binary': '51',
#  'tResult': '43148',
#  'trans man': '12',
#  'trans woman': '36',
#  'transgender': '1',
#  'travesti': '3'}

# %%
percentage_writers = {}
for gender, count in musicWriters.items():
    if gender != "tResult":
        percentage_writers[gender] = (int(count) / allWriters) * 100
print(percentage_writers)
# Out:
# {'male': 73.37535922870121, 'female': 26.33494020580328, 'non-binary': 0.11819783072216557, 'trans woman': 0.08343376286270511, 'genderfluid': 0.027811254287568372, 'trans man': 0.027811254287568372, 'genderqueer': 0.013905627143784186, 'travesti': 0.006952813571892093, 'cisgender female': 0.0023176045239640306, 'cisgender male': 0.0023176045239640306, 'agender': 0.0023176045239640306, 'intersex': 0.0023176045239640306, 'transgender': 0.0023176045239640306}

# %% [markdown]
# # Female composers by country

# %%
wikidata_endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql"

top_nation = '''
SELECT ?person ?personLabel ?countryLabel

WHERE {
  # ?person wdt:P31 wd:Q5.
  # ?person wdt:P106 wd:Q36834.
  # ?person wdt:P21 wd:Q6581072.
  # ?person wdt:P27 ?country.
          
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}

'''

# set the endpoint 
sparql_wd = SPARQLWrapper(wikidata_endpoint)
# set the query
sparql_wd.setQuery(top_nation)
# set the returned format
sparql_wd.setReturnFormat(JSON)
# get the results
# top_nation_result = sparql_wd.query().convert()
female_composers_by_country = sparql_wd.query().convert()

# %%
import json

# Extract the results from the query
results = female_composers_by_country['results']['bindings']

# Initialize an empty list to store the cleaned data
cleaned_data = []

# Iterate through the results and extract the person and country information
for result in results:
    person = result['personLabel']['value']
    country = result['countryLabel']['value']
    cleaned_data.append({'person': person, 'country': country})

# Save the cleaned data to a JSON file
with open("cleaned_data.json", "w") as json_file:
    json.dump(cleaned_data, json_file)

pp.pprint(cleaned_data)
# Out:
# [{'country': 'Kingdom of Castile', 'person': 'Blanche of Castile'},
#  {'country': 'United States of America', 'person': 'Patti Smith'},
#  {'country': 'Romania', 'person': 'Alexandra Stan'},
#  {'country': 'United States of America', 'person': 'Janis Joplin'},
#  {'country': 'United States of America', 'person': 'Cyndi Lauper'},
#  {'country': 'United States of America', 'person': 'Madonna'},
#  {'country': 'United States of America', 'person': 'Ella Fitzgerald'},
#  {'country': 'France', 'person': 'George Sand'},
#  {'country': 'France', 'person': 'Beatritz de Dia'},
#  {'country': 'France', 'person': 'Tibors de Sarenom'},
#  {'country': 'France', 'person': 'Tibors de Sarenom'},
#  {'country': 'France', 'person': 'Maria de Ventadorn'},
#  {'country': 'Germany', 'person': 'Lena Meyer-Landrut'},
#  {'country': 'Electorate of Saxony', 'person': 'Anna Magdalena Bach'},
#  {'country': 'Free City of Frankfurt', 'person': 'Bettina von Arnim'},
#  {'country': 'Confederation of the Rhine', 'person': 'Fanny Mendelssohn'},
#  {'country': 'Kingdom of Prussia', 'person': 'Annette von Droste-Hülshoff'},
#  {'country': 'France', 'person': 'Élisabeth Jacquet de La Guerre'},
#  {'country': 'United Kingdom', 'person': 'Winifred Wagner'},
#  {'country': 'Germany', 'person': 'Winifred Wagner'},
#  {'country': 'Denmark', 'person': 'Caroline Amalie of Augustenburg'},
#  {'country': 'Germany', 'person': 'Caroline Amalie of Augustenburg'},
#  {'country': 'United Kingdom', 'person': 'Sonique'},
#  {'country': 'Germany', 'person': 'Marie of Saxe-Altenburg'},
#  {'country': 'Germany', 'person': 'Maria Antonia Walpurgis of Bavaria'},
#  {'country': 'Germany', 'person': 'Princess Therese of Saxe-Altenburg'},
#  {'country': 'Cuba', 'person': 'Addys Mercedes'},
#  {'country': 'United States of America', 'person': 'Britney Spears'},
#  {'country': 'United States of America', 'person': 'Cher'},
#  {'country': 'United States of America', 'person': 'Sharon Van Etten'},
#  {'country': 'Portugal', 'person': 'Constança Capdeville'},
#  {'country': 'Mytilene', 'person': 'Sappho'},
#  {'country': 'United States of America', 'person': 'Amanda Somerville'},
#  {'country': 'Portugal', 'person': 'Luísa Sobral'},
#  {'country': 'United States of America', 'person': 'Juliana Hatfield'},
#  {'country': 'United States of America', 'person': 'Lisa Zane'},
#  {'country': 'United States of America', 'person': 'Taylor Swift'},
#  {'country': 'Romania', 'person': 'Cornelia Tăutu'},
#  {'country': 'Kingdom of the Netherlands', 'person': 'Tineke Postma'},
#  {'country': 'United Kingdom', 'person': 'Delia Derbyshire'},
#  {'country': 'Canada', 'person': 'Avril Lavigne'},
#  {'country': 'France', 'person': 'Avril Lavigne'},
#  {'country': 'United States of America', 'person': 'Lalaine Vergara-Paras'},
#  {'country': 'United States of America', 'person': 'Patti LaBelle'},
#  {'country': 'United Kingdom', 'person': 'Ellie Goulding'},
#  {'country': 'United Kingdom', 'person': 'Gabrielle Aplin'},
#  {'country': 'United States of America', 'person': 'Kesha'},
#  {'country': 'United States of America', 'person': 'Whitney Houston'},
#  {'country': 'Spain', 'person': 'Shakira'},
#  {'country': 'Colombia', 'person': 'Shakira'},
#  {'country': 'United States of America', 'person': 'Beyoncé'},
#  {'country': 'United States of America', 'person': 'Diana Ross'},
#  {'country': 'Republic of Ireland', 'person': 'Enya'},
#  {'country': 'India', 'person': 'Asha Bhosle'},
#  {'country': 'British Raj', 'person': 'Asha Bhosle'},
#  {'country': 'Portugal', 'person': 'Adelaide Ferreira'},
#  {'country': 'United States of America', 'person': 'Candice King'},
#  {'country': 'United Kingdom', 'person': 'Alma Deutscher'},
#  {'country': 'Australia', 'person': 'Lisa Gerrard'},
#  {'country': 'United States of America', 'person': 'Mariah Carey'},
#  {'country': 'United States of America', 'person': 'Christina Aguilera'},
#  {'country': 'India', 'person': 'Anuradha Paudwal'},
#  {'country': 'Germany', 'person': 'Nico'},
#  {'country': 'United States of America', 'person': 'Candye Kane'},
#  {'country': 'United States of America', 'person': 'Bijou Phillips'},
#  {'country': 'Kingdom of the Netherlands', 'person': 'Anouk'},
#  {'country': 'United States of America', 'person': 'Whoopi Goldberg'},
#  {'country': 'United Kingdom', 'person': 'Daphne Oram'},
#  {'country': 'United Kingdom of Great Britain and Ireland',
#   'person': 'Daphne Oram'},
#  {'country': 'United States of America', 'person': 'Cass Elliot'},
#  {'country': 'Taiwan', 'person': 'Jolin Tsai'},
#  {'country': 'Canada', 'person': 'Lili Haydn'},
#  {'country': 'Brazil', 'person': 'Marisa Monte'},
#  {'country': 'Poland', 'person': 'Eleni Tzoka'},
#  {'country': "Polish People's Republic", 'person': 'Eleni Tzoka'},
#  {'country': 'United States of America', 'person': 'Alicia Keys'},
#  {'country': 'United States of America', 'person': 'Hilary Duff'},
#  {'country': 'France', 'person': 'Pauline Viardot'},
#  {'country': 'Switzerland', 'person': 'Isabelle de Charrière'},
#  {'country': 'Dutch Republic', 'person': 'Isabelle de Charrière'},
#  {'country': 'Germany', 'person': 'Annette Thoma'},
#  {'country': 'Spain', 'person': 'Arianna Savall'},
#  {'country': 'Switzerland', 'person': 'Arianna Savall'},
#  {'country': 'United States of America', 'person': 'Aretha Franklin'},
#  {'country': 'Russia', 'person': 'Nyusha'},
#  {'country': 'Germany', 'person': 'Monika Kampmann'},
#  {'country': 'United States of America', 'person': 'Toni Braxton'},
#  {'country': 'United States of America', 'person': 'Toni Braxton'},
#  {'country': 'Canada', 'person': 'Diana Krall'},
#  {'country': 'United Kingdom', 'person': 'Katie Melua'},
#  {'country': 'Georgia', 'person': 'Katie Melua'},
#  {'country': 'Soviet Union', 'person': 'Katie Melua'},
#  {'country': 'United States of America', 'person': 'Alma Mahler'},
#  {'country': 'Austria', 'person': 'Alma Mahler'},
#  {'country': 'Cisleithania', 'person': 'Alma Mahler'},
#  {'country': 'Spain', 'person': 'Margaret of Austria, Duchess of Savoy'},
#  {'country': 'United States of America', 'person': 'Melanie Safka'},
#  {'country': 'Archbishopric of Salzburg', 'person': 'Anna Mozart'},
#  {'country': 'Cyprus', 'person': 'Evridiki'},
#  {'country': 'Germany', 'person': 'Carolina Eyck'},
#  {'country': 'France', 'person': 'Wanda Landowska'},
#  {'country': 'Russian Empire', 'person': 'Wanda Landowska'},
#  {'country': 'Italy', 'person': 'In-Grid'},
#  {'country': 'United States of America', 'person': 'Ashanti'},
#  {'country': 'United States of America', 'person': 'Bernice Johnson Reagon'},
#  {'country': 'United States of America', 'person': 'Lita Ford'},
#  {'country': 'United States of America', 'person': 'Brandi Carlile'},
#  {'country': 'Russia', 'person': 'Sofia Gubaidulina'},
#  {'country': 'Soviet Union', 'person': 'Sofia Gubaidulina'},
#  {'country': 'Germany', 'person': 'Johanna Kinkel'},
#  {'country': 'Germany', 'person': 'Johanna Kinkel'},
#  {'country': 'Italy', 'person': 'Elisa'},
#  {'country': 'United States of America', 'person': 'Nicole Scherzinger'},
#  {'country': 'United States of America', 'person': 'Taylor Dayne'},
#  {'country': 'United States of America', 'person': 'Thalía'},
#  {'country': 'Mexico', 'person': 'Thalía'},
#  {'country': 'Mexicana', 'person': 'Lucero de Mijares'},
#  {'country': 'Sweden', 'person': 'Agnetha Fältskog'},
#  {'country': 'United States of America', 'person': 'Nina Simone'},
#  {'country': 'Argentina', 'person': 'Victoria Maurette'},
#  {'country': 'France', 'person': 'Édith Lejet'},
#  {'country': 'United States of America', 'person': 'Anne LeBaron'},
#  {'country': 'United States of America', 'person': 'Gloria Coates'},
#  {'country': 'United States of America', 'person': 'Fergie'},
#  {'country': 'United States of America', 'person': 'Dolly Parton'},
#  {'country': 'Japan', 'person': 'Ami Suzuki'},
#  {'country': 'Australia', 'person': 'Sia'},
#  {'country': 'Colombia', 'person': 'Sara Tunes'},
#  {'country': 'United States of America', 'person': 'Carly Simon'},
#  {'country': 'Argentina', 'person': 'Cecilia Pillado'},
#  {'country': 'Turkey', 'person': 'Göksel Demirpençe'},
#  {'country': 'Sweden', 'person': 'Helena Paparizou'},
#  {'country': 'Greece', 'person': 'Helena Paparizou'},
#  {'country': 'Japan', 'person': 'Misia'},
#  {'country': 'Southern Netherlands', 'person': 'Juliana of Liège'},
#  {'country': 'United States of America', 'person': 'Doug E. Fresh'},
#  {'country': 'Sweden', 'person': 'Christina Nilsson'},
#  {'country': 'Kingdom of Prussia',
#   'person': 'Princess Charlotte Frederica of Prussia'},
#  {'country': 'United States of America', 'person': 'Miri Ben-Ari'},
#  {'country': 'United States of America', 'person': 'Kiely Williams'},
#  {'country': 'United States of America', 'person': 'Lissie'},
#  {'country': 'France', 'person': 'Catherine Sauvage'},
#  {'country': 'United States of America', 'person': 'Porcelain Black'},
#  {'country': 'France', 'person': 'Jenifer'},
#  {'country': 'Greece', 'person': 'Eleni Karaindrou'},
#  {'country': 'Japan', 'person': 'Masumi Itō'},
#  {'country': 'Norway', 'person': 'Agathe Backer Grøndahl'},
#  {'country': 'United Kingdom', 'person': 'Rumer'},
#  {'country': 'United States of America', 'person': 'Gloria Jones'},
#  {'country': 'United States of America', 'person': 'Melissa Etheridge'},
#  {'country': 'Puerto Rico', 'person': 'Olga Tañón'},
#  {'country': 'United States of America', 'person': 'Yolanda Adams'},
#  {'country': 'Portugal', 'person': 'Lura'},
#  {'country': 'United States of America', 'person': 'Jackie DeShannon'},
#  {'country': 'Japan', 'person': 'Bonnie Pink'},
#  {'country': 'United States of America', 'person': 'Ester Dean'},
#  {'country': 'United States of America', 'person': 'Irma Thomas'},
#  {'country': 'United States of America', 'person': 'Clara Rockmore'},
#  {'country': 'Russian Empire', 'person': 'Clara Rockmore'},
#  {'country': 'United States of America', 'person': 'Clara Rockmore'},
#  {'country': 'Russian Empire', 'person': 'Clara Rockmore'},
#  {'country': 'Belgium', 'person': 'Désirée Artôt'},
#  {'country': 'Germany', 'person': 'Désirée Artôt'},
#  {'country': 'Germany', 'person': 'Lisa Batiashvili'},
#  {'country': 'Germany', 'person': 'Lisa Batiashvili'},
#  {'country': 'United States of America', 'person': 'Judee Sill'},
#  {'country': 'United States of America', 'person': 'Tessa Thompson'},
#  {'country': 'United States of America', 'person': 'Katelyn Tarver'},
#  {'country': 'Czech Republic', 'person': 'Iva Bittová'},
#  {'country': 'United States of America', 'person': 'Brenda K. Starr'},
#  {'country': 'United States of America', 'person': 'Lauren Alaina'},
#  {'country': 'Sweden', 'person': 'Elisabeth Olin'},
#  {'country': 'Japan', 'person': 'Chiaki Ishikawa'},
#  {'country': 'United States of America', 'person': 'Kina Grannis'},
#  {'country': 'United States of America', 'person': 'Terra Naomi'},
#  {'country': 'South Korea', 'person': 'Unsuk Chin'},
#  {'country': 'Japan', 'person': 'Hitomi Yaida'},
#  {'country': 'United States of America', 'person': 'Kimya Dawson'},
#  {'country': 'United States of America', 'person': 'Kathleen York'},
#  {'country': 'United States of America', 'person': 'Lisa Hartman Black'},
#  {'country': 'France', 'person': 'Claude Arrieu'},
#  {'country': 'Iceland', 'person': 'Eivør Pálsdóttir'},
#  {'country': 'Faroe Islands', 'person': 'Eivør Pálsdóttir'},
#  {'country': 'United States of America', 'person': 'Valaida Snow'},
#  {'country': 'Belgium', 'person': 'Jacqueline Fontyn'},
#  {'country': 'United States of America', 'person': 'Keke Palmer'},
#  {'country': 'Germany', 'person': 'Ilse Fromm-Michaels'},
#  {'country': 'France', 'person': 'Elsa Barraine'},
#  {'country': 'United States of America', 'person': "Mary O'Hara"},
#  {'country': 'United States of America', 'person': 'Patsy Cline'},
#  {'country': 'United States of America', 'person': 'Lil Green'},
#  {'country': 'Australia', 'person': 'Elena Kats-Chernin'},
#  {'country': 'Soviet Union', 'person': 'Elena Kats-Chernin'},
#  {'country': 'United States of America', 'person': 'Allison Balson'},
#  {'country': 'United States of America', 'person': 'Margaret Ruthven Lang'},
#  {'country': 'United Kingdom', 'person': 'Anne Dudley'},
#  {'country': 'Austria', 'person': 'Olga Neuwirth'},
#  {'country': 'Sweden', 'person': 'Amanda Röntgen-Maier'},
#  {'country': 'Canada', 'person': 'Édith Butler'},
#  {'country': 'Germany', 'person': 'Adriana Hölszky'},
#  {'country': 'United States of America', 'person': 'Nivea'},
#  {'country': 'United States of America', 'person': 'Dar Williams'},
#  {'country': 'Australia', 'person': 'Peggy Glanville-Hicks'},
#  {'country': 'Poland', 'person': 'Maria Wodzińska'},
#  {'country': 'Russian Empire', 'person': 'Maria Wodzińska'},
#  {'country': 'United States of America', 'person': 'Tionne Watkins'},
#  {'country': 'South Korea', 'person': 'Younghi Pagh-Paan'},
#  {'country': 'France', 'person': 'Éliane Radigue'},
#  {'country': 'United States of America', 'person': 'Inara George'},
#  {'country': 'United States of America', 'person': 'Melba Liston'},
#  {'country': 'Norway', 'person': 'Rebekka Bakken'},
#  {'country': 'Austrian Empire', 'person': 'Marianna Martines'},
#  {'country': 'United States of America', 'person': 'Sharon Sheeley'},
#  {'country': 'United States of America', 'person': 'Joanna Pacitti'},
#  {'country': 'Russia', 'person': 'Zhanna Bichevskaya'},
#  {'country': 'Soviet Union', 'person': 'Zhanna Bichevskaya'},
#  {'country': 'Poland', 'person': 'Ewa Bem'},
#  {'country': 'Canada', 'person': 'Loreena McKennitt'},
#  {'country': 'France', 'person': 'Éliane Richepin'},
#  {'country': 'France', 'person': 'Elise Caron'},
#  {'country': 'Romania', 'person': 'Violeta Dinescu'},
#  {'country': 'Switzerland', 'person': 'Patricia Kopatchinskaja'},
#  {'country': 'Austria', 'person': 'Patricia Kopatchinskaja'},
#  {'country': 'United Kingdom', 'person': 'Ethel Leginska'},
#  {'country': 'United States of America', 'person': 'Maria Taylor'},
#  {'country': 'United States of America', 'person': 'Pamelia Kurstin'},
#  {'country': 'United States of America', 'person': 'Myra Melford'},
#  {'country': 'Italy', 'person': 'Diana Winter'},
#  {'country': 'United States of America', 'person': 'Brisa Roché'},
#  {'country': 'United States of America', 'person': 'Bebe Buell'},
#  {'country': 'United Kingdom', 'person': 'Marian McPartland'},
#  {'country': 'United Kingdom of Great Britain and Ireland',
#   'person': 'Marian McPartland'},
#  {'country': 'United States of America', 'person': 'Susan Tedeschi'},
#  {'country': 'Soviet Union', 'person': 'Zara Levina'},
#  {'country': 'Poland', 'person': 'Urszula Dudziak'},
#  {'country': 'Italy', 'person': 'Irma Ravinale'},
#  {'country': 'Kingdom of Italy', 'person': 'Irma Ravinale'},
#  {'country': 'Turkey', 'person': 'Şehrazat'},
#  {'country': 'United States of America', 'person': 'Carol E Barnett'},
#  {'country': 'United Kingdom', 'person': 'Jennie Muskett'},
#  {'country': 'Poland', 'person': 'Agata Zubel'},
#  {'country': 'United States of America', 'person': 'Suzanne Ciani'},
#  {'country': 'Estonia', 'person': 'Age Veeroos'},
#  {'country': 'France', 'person': 'Agnelle Bundervoët'},
#  {'country': 'Germany', 'person': 'Agnes Elisabeth Overbeck'},
#  {'country': 'Germany', 'person': 'Agnes Ponizil'},
#  {'country': 'Japan', 'person': 'Ai'},
#  {'country': 'United States of America', 'person': 'Ai'},
#  {'country': 'Japan', 'person': 'Ai Takekawa'},
#  {'country': 'Spain', 'person': 'Macu González'},
#  {'country': 'United Kingdom', 'person': 'Aino Laos'},
#  {'country': 'Finland', 'person': 'Aino Sibelius'},
#  {'country': 'Argentina', 'person': 'Aitana Kasulin'},
#  {'country': 'Japan', 'person': 'Akemi Kuniyoshi-Kuhn'},
#  {'country': 'Japan', 'person': 'Aki Takase'},
#  {'country': 'Japan', 'person': 'Akiko Tsuruga'},
#  {'country': 'Moldova', 'person': 'Yulia Tsibulskaya'},
#  {'country': 'Germany', 'person': 'Alexandra'},
#  {'country': 'Venezuela', 'person': 'Conny Méndez'},
#  {'country': 'Italy', 'person': 'Elena Ledda'},
#  {'country': 'Canada', 'person': 'Jane Bunnett'},
#  {'country': 'France', 'person': 'Rosè'},
#  {'country': 'Canada', 'person': 'Rita Joe'},
#  {'country': 'Canada', 'person': 'Rita Joe'},
#  {'country': 'United States of America', 'person': 'Neko Case'},
#  {'country': 'United States of America', 'person': 'Mashonda'},
#  {'country': 'United States of America', 'person': 'Barbara Tucker'},
#  {'country': 'United States of America', 'person': 'Natasha Shneider'},
#  {'country': 'Soviet Union', 'person': 'Natasha Shneider'},
#  {'country': 'Argentina', 'person': 'Isabel Aretz'},
#  {'country': 'United States of America', 'person': 'Gladys Bentley'},
#  {'country': 'France', 'person': 'Jeanine Rueff'},
#  {'country': 'France', 'person': 'Jeanine Rueff'},
#  {'country': 'France', 'person': 'Louise Héritte-Viardot'},
#  {'country': 'United Kingdom', 'person': 'Liane Carroll'},
#  {'country': 'United States of America', 'person': 'Aleksa Palladino'},
#  {'country': 'Poland', 'person': 'Kayah'},
#  {'country': 'Israel', 'person': 'Dana Berger'},
#  {'country': 'Germany', 'person': 'Eleonore Juliane of Brandenburg-Ansbach'},
#  {'country': 'Iceland', 'person': 'Hildur Guðnadóttir'},
#  {'country': 'United States of America', 'person': 'Gia Farrell'},
#  {'country': 'India', 'person': 'Asha Puthli'},
#  {'country': 'United States of America', 'person': 'Tanya Donelly'},
#  {'country': 'Poland', 'person': 'Elżbieta Sikora'},
#  {'country': 'France', 'person': 'Elżbieta Sikora'},
#  {'country': 'Kingdom of Sardinia', 'person': 'Isabella Leonarda'},
#  {'country': 'United States of America', 'person': 'Kathleen Brennan'},
#  {'country': 'United States of America', 'person': 'Marilyn Mazur'},
#  {'country': 'United States of America', 'person': 'Angela Bofill'},
#  {'country': 'Austria-Hungary', 'person': 'Ilse Weber'},
#  {'country': 'Czechoslovakia', 'person': 'Ilse Weber'},
#  {'country': 'United States of America', 'person': 'Mary Rodgers'},
#  {'country': 'United States of America', 'person': 'Maria Schneider'},
#  {'country': 'United States of America', 'person': 'Dorothy Fields'},
#  {'country': 'United States of America', 'person': 'Kristin Hersh'},
#  {'country': 'Canada', 'person': 'Barbara Pentland'},
#  {'country': 'Brazil', 'person': 'Guiomar Novaes'},
#  {'country': 'United States of America', 'person': 'Michelle Shocked'},
#  {'country': 'Japan', 'person': 'Chihiro Onitsuka'},
#  {'country': 'Japan', 'person': 'Doji Morita'},
#  {'country': 'South Korea', 'person': 'Yeol Eum Son'},
#  {'country': "People's Republic of China", 'person': 'Wu Man'},
#  {'country': 'United States of America', 'person': 'Deborah Drattell'},
#  {'country': 'United States of America', 'person': 'Toshiko Akiyoshi'},
#  {'country': 'Hungary', 'person': 'Erzsébet Házy'},
#  {'country': 'Belgium', 'person': 'Marie Pleyel'},
#  {'country': 'France', 'person': 'Marie Pleyel'},
#  {'country': 'Greece', 'person': 'Dimitra Galani'},
#  {'country': 'Argentina', 'person': 'María Luisa Anido'},
#  {'country': 'Russia', 'person': 'Anna Lesko'},
#  {'country': 'Moldova', 'person': 'Anna Lesko'},
#  {'country': 'Romania', 'person': 'Anna Lesko'},
#  {'country': 'Greece', 'person': 'Nena Venetsanou'},
#  {'country': 'United States of America', 'person': 'Jonatha Brooke'},
#  {'country': 'United States of America', 'person': 'Carla Kihlstedt'},
#  {'country': 'Iceland', 'person': 'Vigdís Grímsdóttir'},
#  {'country': 'United Kingdom', 'person': 'Sidonie Goossens'},
#  {'country': 'United Kingdom of Great Britain and Ireland',
#   'person': 'Sidonie Goossens'},
#  {'country': 'United States of America', 'person': 'Carrie Rodriguez'},
#  {'country': 'Japan', 'person': 'Mayako Kubo'},
#  {'country': 'United Kingdom', 'person': 'Debbie Wiseman'},
#  {'country': 'Sweden', 'person': 'Käbi Laretei'},
#  {'country': 'Estonia', 'person': 'Käbi Laretei'},
#  {'country': 'Estonia', 'person': 'Miina Härma'},
#  {'country': 'Russian Empire', 'person': 'Miina Härma'},
#  {'country': 'Denmark', 'person': 'Debbie Cameron'},
#  {'country': 'South Africa', 'person': 'Mira Calix'},
#  {'country': 'France', 'person': 'Ida Presti'},
#  {'country': 'United States of America', 'person': 'Laura Gibson'},
#  {'country': 'Italy', 'person': 'Francesca Michielin'},
#  {'country': 'Japan', 'person': 'Sachiko Kobayashi'},
#  {'country': 'Switzerland', 'person': 'Iris Szeghy'},
#  {'country': 'Slovakia', 'person': 'Iris Szeghy'},
#  {'country': 'United States of America', 'person': 'Joan Osborne'},
#  {'country': 'United States of America', 'person': 'Dev'},
#  {'country': 'United States of America', 'person': 'Julieta Venegas'},
#  {'country': 'Mexico', 'person': 'Julieta Venegas'},
#  {'country': 'Republic of Venice', 'person': 'Barbara Strozzi'},
#  {'country': 'Spain', 'person': 'Alicia de Larrocha'},
#  {'country': 'United States of America', 'person': 'Karen Black'},
#  {'country': 'United States of America', 'person': 'Cat Power'},
#  {'country': 'United States of America', 'person': 'Macy Gray'},
#  {'country': 'United States of America', 'person': 'Ani DiFranco'},
#  {'country': 'Italy', 'person': 'Gianna Nannini'},
#  {'country': 'Italy', 'person': 'Sabrina Salerno'},
#  {'country': 'South Korea', 'person': 'Lee Hyori'},
#  {'country': 'Denmark', 'person': 'Medina'},
#  {'country': 'Mexico', 'person': 'Consuelo Velázquez'},
#  {'country': 'France', 'person': 'Maria Malibran'},
#  {'country': 'United States of America', 'person': 'Koko Taylor'},
#  {'country': 'Iceland', 'person': 'Emilíana Torrini'},
#  {'country': 'United States of America', 'person': 'Joanna Newsom'},
#  {'country': 'United States of America', 'person': 'Vanessa Carlton'},
#  {'country': 'United States of America', 'person': 'Keyshia Cole'},
#  {'country': 'United Kingdom', 'person': 'Beth Gibbons'},
#  {'country': 'United States of America', 'person': 'Tila Tequila'},
#  {'country': 'Singapore', 'person': 'Tila Tequila'},
#  {'country': 'Sweden', 'person': 'Neneh Cherry'},
#  {'country': 'United States of America', 'person': 'Helen Reddy'},
#  {'country': 'Australia', 'person': 'Helen Reddy'},
#  {'country': 'United States of America', 'person': 'Amerie'},
#  {'country': 'Japan', 'person': 'Hiromi Uehara'},
#  {'country': 'United States of America', 'person': 'Malese Jow'},
#  {'country': 'United States of America', 'person': 'Diamanda Galás'},
#  {'country': 'United States of America', 'person': 'Dee Dee Bridgewater'},
#  {'country': 'United States of America', 'person': 'Lisa "Left Eye" Lopes'},
#  {'country': 'United States of America', 'person': 'Carla Bley'},
#  {'country': 'United States of America', 'person': 'Mýa'},
#  {'country': 'United States of America', 'person': 'Skylar Grey'},
#  {'country': 'United States of America', 'person': 'Debbie Gibson'},
#  {'country': 'United States of America', 'person': 'Elizabeth McGovern'},
#  {'country': 'United States of America', 'person': 'Sunny'},
#  {'country': 'South Korea', 'person': 'Sunny'},
#  {'country': 'Estonia', 'person': 'Kerli'},
#  {'country': 'United States of America', 'person': 'Kate Voegele'},
#  {'country': 'South Korea', 'person': 'Hyuna'},
#  {'country': 'Sweden', 'person': 'Emilia Rydberg'},
#  {'country': 'Spain', 'person': 'Adelina Patti'},
#  {'country': 'Kingdom of Italy', 'person': 'Adelina Patti'},
#  {'country': 'United Kingdom', 'person': 'Marina Diamandis'},
#  {'country': 'Germany', 'person': 'Aziza Mustafa Zadeh'},
#  {'country': 'Azerbaijan', 'person': 'Aziza Mustafa Zadeh'},
#  {'country': 'Soviet Union', 'person': 'Aziza Mustafa Zadeh'},
#  {'country': 'United States of America', 'person': 'Melody Gardot'},
#  {'country': 'Japan', 'person': 'Ringo Sheena'},
#  {'country': 'Spain', 'person': 'Pastora Soler'},
#  {'country': 'United States of America', 'person': 'Bonnie Raitt'},
#  {'country': 'France', 'person': 'Émilie Simon'},
#  {'country': 'United States of America', 'person': 'Laura Nyro'},
#  {'country': 'United States of America', 'person': 'Laurie Anderson'},
#  {'country': 'Republic of Ireland', 'person': 'Sharon Corr'},
#  {'country': 'United States of America', 'person': 'Mare Winningham'},
#  {'country': 'Japan', 'person': 'Angela Aki'},
#  {'country': 'United States of America', 'person': 'Pat Benatar'},
#  {'country': 'United States of America', 'person': 'Michelle Phillips'},
#  {'country': 'France', 'person': 'Yvonne Loriod'},
#  {'country': 'United States of America', 'person': 'Janis Ian'},
#  {'country': 'United States of America', 'person': 'Rachael Yamagata'},
#  {'country': 'Belgium', 'person': 'Axelle Red'},
#  {'country': 'United States of America', 'person': 'Amy Beach'},
#  {'country': 'Sweden', 'person': 'Lena Philipsson'},
#  {'country': 'France', 'person': 'Emma Shapplin'},
#  {'country': 'United States of America', 'person': 'Gladys Knight'},
#  {'country': 'Belgium', 'person': 'Hadise'},
#  {'country': 'Turkey', 'person': 'Hadise'},
#  {'country': 'Israel', 'person': 'Mira Awad'},
#  {'country': 'Germany', 'person': 'Nicole'},
#  {'country': 'United States of America', 'person': 'AJ Michalka'},
#  {'country': 'United States of America', 'person': 'Aly Michalka'},
#  {'country': 'United States of America', 'person': 'Suzanne Vega'},
#  {'country': 'United Kingdom', 'person': 'Tanita Tikaram'},
#  {'country': 'Malaysia', 'person': 'Tanita Tikaram'},
#  {'country': 'United States of America', 'person': 'Linda Perry'},
#  {'country': 'United Kingdom', 'person': 'Petula Clark'},
#  {'country': 'United States of America', 'person': 'Alicia Witt'},
#  {'country': 'United States of America', 'person': 'Faith Evans'},
#  {'country': 'United States of America', 'person': 'Stacie Orrico'},
#  {'country': 'United States of America', 'person': 'Tiffany Young'},
#  {'country': 'South Korea', 'person': 'Tiffany Young'},
#  {'country': 'Brazil', 'person': 'Gal Costa'},
#  {'country': 'Norway', 'person': 'Silje Nergaard'},
#  {'country': 'France', 'person': 'Cécile Chaminade'},
#  {'country': 'United Kingdom', 'person': 'Ethel Smyth'},
#  {'country': 'Canada', 'person': 'Martha Wainwright'},
#  {'country': 'United States of America', 'person': 'Martha Wainwright'},
#  {'country': 'United States of America', 'person': 'Marié Digby'},
#  {'country': 'Japan', 'person': 'Mai Kuraki'},
#  {'country': 'Ukraine', 'person': 'Ani Lorak'},
#  {'country': 'Soviet Union', 'person': 'Ani Lorak'},
#  {'country': 'United States of America', 'person': 'Lisa Marie Presley'},
#  {'country': 'United States of America', 'person': 'Diane Warren'},
#  {'country': 'Mexico', 'person': 'Dulce María'},
#  {'country': 'Japan', 'person': 'Yuna Ito'},
#  {'country': 'Spanish Empire', 'person': 'Juana Inés de la Cruz'},
#  {'country': 'Austria', 'person': 'Zeebee'},
#  {'country': 'United States of America', 'person': 'Zeena Parkins'},
#  {'country': 'Sweden', 'person': 'Marie Fredriksson'},
#  {'country': 'Canada', 'person': 'Mylène Farmer'},
#  {'country': 'France', 'person': 'Mylène Farmer'},
#  {'country': 'United Kingdom', 'person': 'Olivia Newton-John'},
#  {'country': 'Australia', 'person': 'Olivia Newton-John'},
#  {'country': 'United States of America', 'person': 'Dominique Eade'},
#  {'country': 'United States of America', 'person': 'Paula Abdul'},
#  {'country': 'United States of America', 'person': 'Tracy Chapman'},
#  {'country': 'United States of America', 'person': 'Mandy Moore'},
#  {'country': 'Australia', 'person': 'Rebecca St. James'},
#  {'country': 'United States of America', 'person': 'Emily Osment'},
#  {'country': 'Argentina', 'person': 'María Elena Walsh'},
#  {'country': 'United States of America', 'person': 'Amanda Seyfried'},
#  {'country': 'France', 'person': 'Eva Green'},
#  {'country': 'United States of America', 'person': 'Zooey Deschanel'},
#  {'country': 'United Kingdom', 'person': 'Duffy'},
#  {'country': 'Turkey', 'person': 'Sertab Erener'},
#  {'country': 'Turkey', 'person': 'Sertab Erener'},
#  {'country': 'United States of America', 'person': 'Tori Amos'},
#  {'country': 'United Kingdom', 'person': 'Toupie Lowther'},
#  {'country': 'France', 'person': 'Marie Noël'},
#  {'country': 'United Kingdom', 'person': 'Yasmine Hamdan'},
#  {'country': 'Lebanon', 'person': 'Yasmine Hamdan'},
#  {'country': 'Turkey', 'person': 'Zeynep Gedizlioğlu'},
#  {'country': 'Brazil', 'person': 'Sandy'},
#  {'country': 'United States of America', 'person': 'Leighton Meester'},
#  {'country': 'United States of America', 'person': 'Sheryl Crow'},
#  {'country': 'United States of America', 'person': 'Hayley Williams'},
#  {'country': 'Sweden', 'person': 'Emma Härdelin'},
#  {'country': 'United Kingdom', 'person': 'Dido'},
#  {'country': 'United States of America', 'person': 'Ciara'},
#  {'country': 'United States of America', 'person': 'Debby Ryan'},
#  {'country': 'United Kingdom', 'person': 'M.I.A.'},
#  {'country': 'Sri Lanka', 'person': 'M.I.A.'},
#  {'country': 'United States of America', 'person': 'Beth Hart'},
#  {'country': 'Ukraine', 'person': 'Gaitana'},
#  {'country': 'Republic of the Congo', 'person': 'Gaitana'},
#  {'country': 'Ukraine', 'person': 'Svetlana Loboda'},
#  {'country': 'Sweden', 'person': 'Carola Häggkvist'},
#  {'country': 'United States of America', 'person': 'Lauryn Hill'},
#  {'country': 'United States of America', 'person': 'Ruth Schönthal'},
#  {'country': 'Germany', 'person': 'Ruth Schönthal'},
#  {'country': 'United States of America', 'person': 'Debbie Harry'},
#  {'country': 'United Kingdom', 'person': 'Vanessa-Mae'},
#  {'country': 'Singapore', 'person': 'Vanessa-Mae'},
#  {'country': 'Thailand', 'person': 'Vanessa-Mae'},
#  {'country': 'United States of America', 'person': 'JoJo'},
#  {'country': 'United States of America', 'person': 'Jordin Sparks'},
#  {'country': 'United States of America', 'person': 'Carrie Underwood'},
#  {'country': 'Austria', 'person': 'Anna Mahler'},
#  {'country': 'United Kingdom', 'person': 'Sophie Ellis-Bextor'},
#  {'country': 'Brazil', 'person': 'Adriana Calcanhotto'},
#  {'country': 'Poland', 'person': 'Violetta Villas'},
#  {'country': 'United States of America', 'person': 'Carole King'},
#  {'country': 'United Kingdom', 'person': 'Jessie Ware'},
#  {'country': 'United Kingdom', 'person': 'Zoe Rahman'},
#  {'country': 'Poland', 'person': 'Zofia Jasnota'},
#  {'country': 'Poland', 'person': 'Zofia Jasnota'},
#  {'country': 'United Kingdom', 'person': 'PJ Harvey'},
#  {'country': 'United States of America', 'person': 'Courtney Love'},
#  {'country': 'United States of America', 'person': 'Erykah Badu'},
#  {'country': 'Slovakia', 'person': 'Katarína Knechtová'},
#  {'country': 'Japan', 'person': 'Yoko Kanno'},
#  {'country': 'Japan', 'person': 'Yoko Kanno'},
#  {'country': 'Canada', 'person': 'Zoë Keating'},
#  {'country': 'United States of America', 'person': 'Zoë Keating'},
#  {'country': 'United States of America', 'person': 'Jada Pinkett Smith'},
#  {'country': 'Russia', 'person': 'Julia Volkova'},
#  {'country': 'United States of America', 'person': 'Colbie Caillat'},
#  {'country': 'United States of America', 'person': 'Hattie McDaniel'},
#  {'country': 'United States of America', 'person': 'Gloria Gaynor'},
#  {'country': 'United States of America', 'person': 'Jewel'},
#  {'country': 'Ukraine', 'person': 'Tina Karol'},
#  {'country': 'United States of America', 'person': 'Michelle Williams'},
#  {'country': 'United States of America', 'person': 'Regina Spektor'},
#  {'country': 'Soviet Union', 'person': 'Regina Spektor'},
#  {'country': 'United States of America', 'person': 'Katharine McPhee'},
#  {'country': 'United States of America', 'person': 'Christina Perri'},
#  {'country': 'Japan', 'person': 'Nana Mizuki'},
#  {'country': 'Latvia', 'person': 'Marija Naumova'},
#  {'country': 'United States of America', 'person': 'Linda Ronstadt'},
#  {'country': 'United States of America', 'person': 'Chaka Khan'},
#  {'country': 'United States of America', 'person': 'Kimberly Wyatt'},
#  {'country': 'France', 'person': 'Hortense de Beauharnais'},
#  {'country': 'United States of America', 'person': 'Grace Slick'},
#  {'country': 'Finland', 'person': 'Hanna Pakarinen'},
#  {'country': 'Sweden', 'person': 'Petra Marklund'},
#  {'country': 'Brazil', 'person': 'Astrud Gilberto'},
#  {'country': 'France', 'person': 'Lili Boulanger'},
#  {'country': 'United States of America', 'person': 'Bethany Joy Lenz'},
#  {'country': 'United States of America', 'person': 'Sara Bareilles'},
#  {'country': 'England', 'person': 'Cher Lloyd'},
#  {'country': 'United States of America', 'person': 'Christina Milian'},
#  {'country': 'United States of America', 'person': 'Kat DeLuna'},
#  {'country': 'United Kingdom', 'person': 'KT Tunstall'},
#  {'country': 'Spain', 'person': 'Queen Bárbara of Spain'},
#  {'country': 'Poland', 'person': 'Grażyna Bacewicz'},
#  {'country': 'Germany', 'person': 'Princess Philippine Charlotte of Prussia'},
#  {'country': 'Germany', 'person': 'Magdalena Sibylla of Hesse-Darmstadt'},
#  {'country': 'Germany', 'person': 'Katja Riemann'},
#  {'country': 'Germany', 'person': 'Katharina Wagner'},
#  {'country': 'Sweden', 'person': 'Lisa Ekdahl'},
#  {'country': 'Germany', 'person': 'Corona Schröter'},
#  {'country': 'Germany', 'person': 'Meret Becker'},
#  {'country': 'Germany', 'person': 'Vanessa Petruo'},
#  {'country': 'Germany', 'person': 'Jasmin Tabatabai'},
#  {'country': 'Iran', 'person': 'Jasmin Tabatabai'},
#  {'country': 'West Germany', 'person': 'Jasmin Tabatabai'},
#  {'country': 'Germany', 'person': 'Sophie Menter'},
#  {'country': 'Germany', 'person': 'Gudrun Wagner'},
#  {'country': 'Germany', 'person': 'Jessica Wahls'},
#  {'country': 'Kingdom of Saxony', 'person': 'Princess Maria Amalie of Saxony'},
#  {'country': 'Germany', 'person': 'Edith Picht-Axenfeld'},
#  {'country': 'Germany', 'person': 'Friedelind Wagner'},
#  {'country': 'Germany', 'person': 'Hildegard of Bingen'},
#  {'country': 'Electoral Palatinate', 'person': 'Hildegard of Bingen'},
#  {'country': 'Germany', 'person': 'Monika Kruse'},
#  {'country': 'Germany', 'person': 'Isabel Mundry'},
#  {'country': 'Germany', 'person': 'Kristina Bach'},
#  {'country': 'Germany', 'person': 'Eva Wagner-Pasquier'},
#  {'country': 'United States of America', 'person': 'Meshell Ndegeocello'},
#  {'country': 'Norway', 'person': 'Anne-Marie Giørtz'},
#  {'country': 'Sweden', 'person': 'Anna Järvinen'},
#  {'country': 'German Empire', 'person': 'Cosima Wagner'},
#  {'country': 'Germany', 'person': 'Sandra Nasić'},
#  {'country': 'Germany', 'person': 'Mary Wigman'},
#  {'country': 'Germany', 'person': 'Juliane Werding'},
#  {'country': 'Kingdom of Saxony', 'person': 'Minna Planer'},
#  {'country': 'Austrian Empire', 'person': 'Karoline Pichler'},
#  {'country': 'Austria', 'person': 'Aloysia Weber'},
#  {'country': 'Archduchy of Austria', 'person': 'Caterina Cavalieri'},
#  {'country': 'United States of America', 'person': 'Ann Hampton Callaway'},
#  {'country': 'United States of America', 'person': 'Ann Hampton Callaway'},
#  {'country': 'Russia', 'person': 'Alla Pugacheva'},
#  {'country': 'Cyprus', 'person': 'Alla Pugacheva'},
#  {'country': 'Germany', 'person': 'Nina Gerhard'},
#  {'country': 'Austria', 'person': 'Manon Gropius'},
#  {'country': 'Austria', 'person': 'Johanna Doderer'},
#  {'country': 'Germany', 'person': 'Elise Polko'},
#  {'country': 'Austria', 'person': 'Franziska Batthyány'},
#  {'country': 'Austria', 'person': 'Grete von Zieritz'},
#  {'country': 'Austria', 'person': 'Paula von Preradović'},
#  {'country': 'Austria', 'person': 'Mathilde Kralik'},
#  {'country': 'Germany', 'person': 'Nike Wagner'},
#  {'country': 'Austria', 'person': 'Therese Malfatti'},
#  {'country': 'Austria', 'person': 'Renate Spitzner'},
#  {'country': 'Germany', 'person': 'Helene Liebmann'},
#  {'country': 'Germany', 'person': 'Ulrike Haage'},
#  {'country': 'Germany', 'person': 'Princess Louise of Saxe-Meiningen'},
#  {'country': 'Germany', 'person': 'Mathilde Hannah von Rothschild'},
#  {'country': 'Germany', 'person': 'Suzanne Doucet'},
#  {'country': 'German Confederation', 'person': 'Emilie Zumsteeg'},
#  {'country': 'Germany', 'person': 'Limpe Fuchs'},
#  {'country': 'German Reich', 'person': 'Gertrud Grunow'},
#  {'country': 'Germany', 'person': 'Ursula Herking'},
#  {'country': 'Poland', 'person': 'Leni Alexander'},
#  {'country': 'Germany', 'person': 'Leni Alexander'},
#  {'country': 'Chile', 'person': 'Leni Alexander'},
#  {'country': 'United States of America', 'person': 'Billie Holiday'},
#  {'country': 'Germany', 'person': 'Ruth Zechlin'},
#  {'country': 'German Democratic Republic', 'person': 'Ruth Zechlin'},
#  {'country': 'Kingdom of Hawaiʻi', 'person': 'Liliʻuokalani'},
#  {'country': 'Japan', 'person': 'Akiko Yano'},
#  {'country': 'Bulgaria', 'person': 'Anna-Maria Ravnopolska-Dean'},
#  {'country': 'Germany', 'person': 'Wilhelmina Koch'},
#  {'country': 'United States of America', 'person': 'Julie Delpy'},
#  {'country': 'France', 'person': 'Julie Delpy'},
#  {'country': 'Israel', 'person': 'Ofra Haza'},
#  {'country': 'Germany', 'person': 'Barbara Lahr'},
#  {'country': 'Germany', 'person': 'Barbara Heller'},
#  {'country': 'Soviet Union', 'person': 'Ella Adayevskaya'},
#  {'country': 'Russian Empire', 'person': 'Ella Adayevskaya'},
#  {'country': 'Weimar Republic', 'person': 'Ella Adayevskaya'},
#  {'country': 'German Empire', 'person': 'Ella Adayevskaya'},
#  {'country': 'Norway', 'person': 'Simone Eriksrud'},
#  {'country': 'Germany', 'person': 'Simone Eriksrud'},
#  {'country': 'United States of America', 'person': 'Winifred Hyson'},
#  {'country': 'Czech Republic', 'person': 'Věra Bílá'},
#  {'country': 'Germany', 'person': 'Nannette Streicher'},
#  {'country': 'Switzerland', 'person': 'Elina Duni'},
#  {'country': 'Albania', 'person': 'Elina Duni'},
#  {'country': 'New Zealand', 'person': 'Fran Walsh'},
#  {'country': 'Japan', 'person': 'Yoko Ono'},
#  {'country': 'United States of America', 'person': 'Yoko Ono'},
#  {'country': 'Switzerland', 'person': 'Sylvie Courvoisier'},
#  {'country': 'Portugal', 'person': 'Dina'},
#  {'country': 'Canada', 'person': 'Grimes'},
#  {'country': 'Poland', 'person': 'Ewelina Nowicka'},
#  {'country': 'Kingdom of Prussia', 'person': 'Delphine von Schauroth'},
#  {'country': 'United States of America', 'person': 'Meredith Brooks'},
#  {'country': 'United States of America', 'person': 'Natalie Merchant'},
#  {'country': 'United States of America', 'person': 'Alice Coltrane'},
#  {'country': 'Japan', 'person': 'Mitsuko Uchida'},
#  {'country': 'United Kingdom', 'person': 'Mitsuko Uchida'},
#  {'country': 'United States of America', 'person': 'Jennifer Paige'},
#  {'country': 'United States of America', 'person': 'Jennifer Warnes'},
#  {'country': 'United States of America', 'person': 'Esperanza Spalding'},
#  {'country': 'United States of America', 'person': 'St. Vincent'},
#  {'country': 'United States of America', 'person': 'Uffie'},
#  {'country': 'France', 'person': 'Uffie'},
#  {'country': 'Republic of Ireland', 'person': 'Moya Brennan'},
#  {'country': 'United States of America', 'person': 'Yma Sumac'},
#  {'country': 'Peru', 'person': 'Yma Sumac'},
#  {'country': 'United States of America', 'person': 'Hayley Kiyoko'},
#  {'country': 'United States of America', 'person': 'Chrissie Hynde'},
#  {'country': 'United Kingdom', 'person': 'Evelyn Glennie'},
#  {'country': 'Japan', 'person': 'Ayaka'},
#  {'country': 'United States of America', 'person': 'Eve'},
#  {'country': 'Germany', 'person': 'Barbara Buchholz'},
#  {'country': 'United States of America', 'person': 'Aimee Mann'},
#  {'country': 'United States of America', 'person': 'Aimee Mann'},
#  {'country': 'France', 'person': 'Yvette Guilbert'},
#  {'country': 'Australia', 'person': 'Tina Arena'},
#  {'country': 'United States of America', 'person': 'Nadia Ali'},
#  {'country': 'South Korea', 'person': 'Seo Joo-hyun'},
#  {'country': 'United States of America', 'person': 'Santigold'},
#  {'country': 'United States of America', 'person': 'Amanda Palmer'},
#  {'country': 'United States of America', 'person': 'Maureen Tucker'},
#  {'country': 'United Kingdom', 'person': 'Janet Baker'},
#  {'country': 'Italy', 'person': 'Alexia'},
#  {'country': 'Germany',
#   'person': 'Duchess Anna Amalia of Brunswick-Wolfenbüttel'},
#  {'country': 'Saxe-Weimar-Eisenach',
#   'person': 'Duchess Anna Amalia of Brunswick-Wolfenbüttel'},
#  {'country': 'Finland', 'person': 'Kaija Saariaho'},
#  {'country': 'Venezuela', 'person': 'Teresa Carreño'},
#  {'country': 'United States of America', 'person': 'Lera Auerbach'},
#  {'country': 'Austria', 'person': 'Lera Auerbach'},
#  {'country': 'Soviet Union', 'person': 'Lera Auerbach'},
#  {'country': 'United States of America', 'person': 'Angie Stone'},
#  {'country': 'United Kingdom', 'person': 'Lucie Silvas'},
#  {'country': 'United Kingdom', 'person': 'Amelle Berrabah'},
#  {'country': 'Japan', 'person': 'Kanon Wakeshima'},
#  {'country': 'Switzerland', 'person': 'Francine Jordi'},
#  {'country': 'Canada', 'person': 'Lights'},
#  {'country': 'Canada', 'person': 'Lights'},
#  {'country': 'Russia', 'person': 'Zemfira'},
#  {'country': 'Sweden', 'person': 'Meja'},
#  {'country': 'United States of America', 'person': 'Laura Marano'},
#  {'country': 'United States of America', 'person': 'Krystal Meyers'},
#  {'country': 'United States of America', 'person': 'Ingrid Michaelson'},
#  {'country': 'Norway', 'person': 'Anja Garbarek'},
#  {'country': 'United States of America', 'person': 'Natalie Curtis'},
#  {'country': 'United States of America', 'person': 'Skin Diamond'},
#  {'country': 'United States of America', 'person': 'Crystal Waters'},
#  {'country': 'Japan', 'person': 'Yui'},
#  {'country': 'Japan', 'person': 'Suara'},
#  {'country': 'France', 'person': "Marie d'Agoult"},
#  {'country': 'Japan', 'person': 'Keiko Abe'},
#  {'country': 'Kingdom of the Netherlands',
#   'person': 'Princess Marianne of the Netherlands'},
#  {'country': 'United Kingdom', 'person': 'Sally Oldfield'},
#  {'country': 'United States of America', 'person': 'Matana Roberts'},
#  {'country': 'United States of America', 'person': 'Judy Collins'},
#  {'country': 'United Kingdom', 'person': 'Sarah Harding'},
#  {'country': 'United States of America', 'person': 'Leslie Carter'},
#  {'country': 'Russia', 'person': 'Galina Ustvolskaya'},
#  {'country': 'Soviet Union', 'person': 'Galina Ustvolskaya'},
#  {'country': 'Russian Socialist Federative Soviet Republic',
#   'person': 'Galina Ustvolskaya'},
#  {'country': 'Turkey', 'person': 'Şebnem Ferah'},
#  {'country': 'United States of America', 'person': 'Anita Baker'},
#  {'country': 'United Kingdom', 'person': 'Tasmin Archer'},
#  {'country': 'France', 'person': 'Rokia Traoré'},
#  {'country': 'Mali', 'person': 'Rokia Traoré'},
#  {'country': 'United States of America', 'person': 'Sabrina Bryan'},
#  {'country': 'United States of America', 'person': 'Lucinda Williams'},
#  {'country': 'United States of America', 'person': 'Patti Scialfa'},
#  {'country': 'United States of America', 'person': 'Fanny Crosby'},
#  {'country': "People's Republic of China", 'person': 'Sa Dingding'},
#  {'country': 'United Kingdom', 'person': 'Liz McClarnon'},
#  {'country': 'United States of America', 'person': 'Bebel Gilberto'},
#  {'country': 'Brazil', 'person': 'Bebel Gilberto'},
#  {'country': 'United States of America', 'person': 'Elizabeth Daily'},
#  {'country': 'United Kingdom', 'person': "Des'ree"},
#  {'country': 'United States of America', 'person': 'Matraca Berg'},
#  {'country': 'United States of America', 'person': 'Wendy O. Williams'},
#  {'country': 'France', 'person': 'Lorie'},
#  {'country': 'United States of America', 'person': 'India.Arie'},
#  {'country': 'United States of America', 'person': 'Liz Phair'},
#  {'country': 'United States of America', 'person': 'Rickie Lee Jones'},
#  {'country': 'Cyprus', 'person': 'Alexia Vassiliou'},
#  {'country': 'United States of America', 'person': 'Anoushka Shankar'},
#  {'country': 'United Kingdom', 'person': 'Anoushka Shankar'},
#  {'country': 'United States of America', 'person': 'Anya Marina'},
#  {'country': 'United Kingdom', 'person': 'Rebecca Clarke'},
#  {'country': 'Russia', 'person': 'Aziza'},
#  {'country': 'Uzbekistan', 'person': 'Aziza'},
#  {'country': 'Soviet Union', 'person': 'Aziza'},
#  {'country': 'Japan', 'person': 'Ceui'},
#  {'country': 'Russia', 'person': 'Tatiana Nikolayeva'},
#  {'country': 'Soviet Union', 'person': 'Tatiana Nikolayeva'},
#  {'country': 'United States of America', 'person': 'Olivia Olson'},
#  {'country': 'United States of America', 'person': 'Mary Lou Williams'},
#  {'country': 'Germany', 'person': 'Carola Bauckholt'},
#  {'country': 'Russia', 'person': 'MakSim'},
#  {'country': 'United States of America', 'person': 'Lee Pui Ming'},
#  {'country': 'United States of America', 'person': 'Lindsey Stirling'},
#  {'country': 'Ukraine', 'person': 'Ruslana'},
#  {'country': 'Soviet Union', 'person': 'Ruslana'},
#  {'country': 'United States of America', 'person': 'Helen Humes'},
#  {'country': 'United Kingdom of Great Britain and Ireland',
#   'person': 'Clara de Chatelain'},
#  {'country': 'Uruguay', 'person': 'Idea Vilariño'},
#  {'country': 'Canada', 'person': 'Alanis Morissette'},
#  {'country': 'United States of America', 'person': 'Alanis Morissette'},
#  {'country': 'United States of America', 'person': 'Janet Jackson'},
#  {'country': 'Canada', 'person': 'Shania Twain'},
#  {'country': 'United States of America', 'person': 'Joan Baez'},
#  {'country': 'Switzerland', 'person': 'Tina Turner'},
#  {'country': 'Kingdom of Saxony', 'person': 'Clara Wieck'},
#  {'country': 'German Reich', 'person': 'Clara Wieck'},
#  {'country': 'Japan', 'person': 'Yuki Kajiura'},
#  {'country': 'United States of America', 'person': 'Marla Gibbs'},
#  {'country': 'United States of America', 'person': 'Myrna Smith'},
#  {'country': 'Republic of Venice', 'person': 'Anna Maria della Pietà'},
#  {'country': 'Finland', 'person': 'Emma Salokoski'},
#  {'country': 'Mexico', 'person': 'Danna Paola'},
#  {'country': 'Austria', 'person': 'Zabine'},
#  {'country': 'France', 'person': 'Nadia Boulanger'},
#  {'country': 'Peru', 'person': 'Damaris'},
#  {'country': 'Canada', 'person': 'Zaho'},
#  {'country': 'Algeria', 'person': 'Zaho'},
#  {'country': 'South Africa', 'person': 'Miriam Makeba'},
#  {'country': 'Union of South Africa', 'person': 'Miriam Makeba'},
#  {'country': 'United States of America', 'person': 'Kat Graham'},
#  {'country': 'United Kingdom', 'person': 'Melanie C'},
#  {'country': 'Peru', 'person': 'Susana Baca'},
#  {'country': 'United States of America', 'person': 'Missy Elliott'},
#  {'country': 'United States of America', 'person': 'Vivian Kubrick'},
#  {'country': 'United States of America', 'person': 'Toni Childs'},
#  {'country': 'German Confederation', 'person': 'Josephine Lang'},
#  {'country': 'German Reich', 'person': 'Josephine Lang'},
#  {'country': 'United States of America', 'person': 'Bebe Barron'},
#  {'country': 'United Kingdom', 'person': 'Barbara Thompson'},
#  {'country': 'Australia', 'person': 'Lenka'},
#  {'country': 'Kingdom of the Netherlands', 'person': 'Wende'},
#  {'country': 'Canada', 'person': 'Julia Kent'},
#  {'country': 'United States of America', 'person': 'Charlotte Martin'},
#  {'country': 'United States of America', 'person': 'May Aufderheide'},
#  {'country': 'Poland', 'person': 'Joanna Bruzdowicz'},
#  {'country': 'France', 'person': 'Joanna Bruzdowicz'},
#  {'country': 'Russia', 'person': 'Elena Frolova'},
#  {'country': 'United States of America', 'person': 'Diane Birch'},
#  {'country': 'Russia', 'person': 'Alla Bayanova'},
#  {'country': 'Romania', 'person': 'Alla Bayanova'},
#  {'country': 'Soviet Union', 'person': 'Alla Bayanova'},
#  {'country': 'Russian Empire', 'person': 'Alla Bayanova'},
#  {'country': 'United States of America', 'person': 'Mindi Abair'},
#  {'country': 'United Kingdom', 'person': 'Nicola LeFanu'},
#  {'country': 'Kingdom of the Netherlands', 'person': 'Daisy Dee'},
#  {'country': 'United States of America', 'person': 'Gillian Welch'},
#  {'country': 'United States of America', 'person': 'Diana L. Paxson'},
#  {'country': 'Italy', 'person': 'Emma Marrone'},
#  {'country': 'Czech Republic', 'person': 'Sylvie Bodorová'},
#  {'country': 'Israel', 'person': 'Betty Olivero'},
#  {'country': 'Czech Republic', 'person': 'Zuzana Navarová'},
#  {'country': 'United States of America', 'person': 'Solange Knowles'},
#  {'country': 'United States of America', 'person': 'Julie London'},
#  {'country': 'France', 'person': 'Angélique Kidjo'},
#  {'country': 'Benin', 'person': 'Angélique Kidjo'},
#  {'country': 'Japan', 'person': 'Ai Otsuka'},
#  {'country': 'United States of America', 'person': 'Monica'},
#  {'country': 'United States of America', 'person': 'Christina Grimmie'},
#  {'country': 'United States of America', 'person': 'Kristin Chenoweth'},
#  {'country': 'United States of America', 'person': 'Natalie Cole'},
#  {'country': 'Grand Duchy of Tuscany', 'person': 'Francesca Caccini'},
#  {'country': 'United States of America', 'person': 'Lil Mama'},
#  {'country': 'Denmark', 'person': 'Christina Chanée'},
#  {'country': 'Italy', 'person': 'Mia Martini'},
#  {'country': 'United Kingdom', 'person': 'Kate Nash'},
#  {'country': 'United Kingdom', 'person': 'Susan George'},
# ...
#  {'country': 'Cameroon', 'person': 'Vernyuy Tina'},
#  {'country': 'Cuba', 'person': 'Dayami Lozada'},
#  {'country': 'Russia', 'person': 'Q109913015'},
#  {'country': 'Kingdom of the Netherlands', 'person': 'Gon Voorhoeve'},
#  {'country': 'Norway', 'person': 'Caroline Wolla Sørlie'},
#  {'country': 'Denmark', 'person': 'Ellida Kjeldsen'},
#  {'country': 'Norway', 'person': 'Dagny Bøe'},
#  {'country': 'Czech Republic', 'person': 'Marta Soukupová'},
#  {'country': 'Czech Republic', 'person': 'Vladimira Krckova'},
#  {'country': 'Kingdom of the Netherlands', 'person': 'Jetty Podt'},
#  {'country': 'Austria', 'person': 'Mira Lu Kovacs'},
#  {'country': 'United States of America', 'person': 'Helen Steele'},
#  {'country': 'Greece', 'person': 'Eirini Aspioti'},
#  {'country': 'Austria', 'person': 'Maria Brossement'},
#  {'country': 'Georgia', 'person': 'Marina Adamia'},
#  {'country': 'Soviet Union', 'person': 'Marina Adamia'},
#  {'country': 'Georgia', 'person': 'Marina Adamia'},
#  {'country': 'Soviet Union', 'person': 'Marina Adamia'},
#  {'country': 'Cisleithania', 'person': 'Berta Hermann'},
#  {'country': 'Finland', 'person': 'Mari Sainio'},
#  {'country': 'Israel', 'person': 'Q110198579'},
#  {'country': 'France', 'person': 'M. Fiorelli'},
#  {'country': 'France', 'person': 'M. Fiorelli'},
#  {'country': 'France', 'person': 'Blanche Lucas'},
#  {'country': 'France', 'person': 'Blanche Lucas'},
#  {'country': 'France', 'person': 'Germaine Albert-Birot'},
#  {'country': 'Finland', 'person': 'Diana Ringo'},
#  {'country': 'Kingdom of the Netherlands', 'person': 'Renske Vrolijk'},
#  {'country': 'United Kingdom of Great Britain and Ireland',
#   'person': 'Hope Squire'},
#  {'country': 'Spain', 'person': 'Noa Lur'},
#  {'country': 'Benin', 'person': 'Somissou'},
#  {'country': 'United States of America', 'person': 'Louise Spizizen'},
#  {'country': 'Peru', 'person': 'Ania'},
#  {'country': 'France', 'person': 'Laure Collin'},
#  {'country': 'France', 'person': 'Henriette Colom'},
#  {'country': 'France', 'person': 'Marcelle Combes'},
#  {'country': 'France', 'person': 'Suzanne Coquelin'},
#  {'country': 'France', 'person': 'Germaine Corbin'},
#  {'country': 'France', 'person': 'Sophie de Courpon'},
#  {'country': 'United Kingdom', 'person': 'Caroline Creyke'},
#  {'country': 'France', 'person': 'Jeanne Danglas'},
#  {'country': 'France', 'person': 'Gabrielle Dauly'},
#  {'country': 'France', 'person': 'Marguerite Debrie'},
#  {'country': 'France', 'person': 'Elizabeth Delacour-Bonnamour'},
#  {'country': 'France', 'person': 'Isabelle Delâge-Prat'},
#  {'country': 'France', 'person': 'Madame C. Delaunay-Gaëtan'},
#  {'country': 'France', 'person': 'Gilbert Des Roches'},
#  {'country': 'France', 'person': 'Jeanne Descaves'},
#  {'country': 'France', 'person': 'Mathilde Desliens'},
#  {'country': 'France', 'person': 'Jacqueline Despas'},
#  {'country': 'France', 'person': 'Charlotte Dévéria'},
#  {'country': 'France', 'person': 'Louise Didier'},
#  {'country': 'France', 'person': 'Marie-Antoinette Didierjean'},
#  {'country': 'France', 'person': 'Célestine Doré'},
#  {'country': 'Belgium', 'person': 'Madeleine du Bois'},
#  {'country': 'France', 'person': 'P. du Bourg'},
#  {'country': 'France', 'person': 'Madeleine Dubois'},
#  {'country': 'France', 'person': 'Marie-Catherine-Césarine Duchamp'},
#  {'country': 'France', 'person': 'Marthe Ducourau'},
#  {'country': 'France', 'person': 'Cécile Dufresne'},
#  {'country': 'France', 'person': 'Berthe Mariani'},
#  {'country': 'France', 'person': 'Lise Borel'},
#  {'country': 'United Kingdom', 'person': 'Carol Canning'},
#  {'country': 'Republic of Ireland', 'person': 'Solfa Carlile'},
#  {'country': 'United States of America', 'person': 'Mary Carpenter Davis'},
#  {'country': 'France', 'person': 'Celine Castano'},
#  {'country': 'France', 'person': 'Clémentine Charuel'},
#  {'country': 'Israel', 'person': 'Nira Chen'},
#  {'country': 'France', 'person': 'Karine Choual'},
#  {'country': 'United States of America', 'person': 'Karen Christianson'},
#  {'country': 'United States of America', 'person': 'Nancy Hill Cobb'},
#  {'country': 'United States of America', 'person': 'Emily Crocker'},
#  {'country': 'United States of America', 'person': 'Betty Dardess'},
#  {'country': 'United States of America', 'person': 'Thelma Davis'},
#  {'country': 'United States of America', 'person': 'Victoria Davison'},
#  {'country': 'United States of America', 'person': 'Lisa Despain'},
#  {'country': 'United States of America', 'person': 'Eileen Diamond'},
#  {'country': 'United States of America', 'person': 'Lee Ann Dresser'},
#  {'country': 'Germany', 'person': 'Christiane Dusza'},
#  {'country': 'United States of America', 'person': 'Donna Kelly Eastman'},
#  {'country': 'Sweden', 'person': 'Nina Hobert'},
#  {'country': 'United States of America', 'person': 'Loretta Ellenberger'},
#  {'country': 'United States of America', 'person': 'Thea Sikora Engelson'},
#  {'country': 'France', 'person': 'Catherine Fender'},
#  {'country': 'Poland', 'person': 'Sylvia Filus'},
#  {'country': 'France', 'person': 'Sylvia Filus'},
#  {'country': 'France', 'person': 'Paulette Firbach'},
#  {'country': 'United States of America', 'person': 'Ellen Fishman-Johnson'},
#  {'country': 'France', 'person': 'Heloisa Fleury'},
#  {'country': 'Brazil', 'person': 'Heloisa Fleury'},
#  {'country': 'France', 'person': 'Alix Flouest'},
#  {'country': 'United States of America', 'person': 'Lisa Foland'},
#  {'country': 'United States of America', 'person': 'Paula Foley Tillen'},
#  {'country': 'France', 'person': 'Julie Fondard'},
#  {'country': 'France', 'person': 'Jane Fonssagrives'},
#  {'country': 'France', 'person': 'Julia Fortier'},
#  {'country': 'Venezuela', 'person': 'Oksana Linde'},
#  {'country': 'Brazil', 'person': 'Daniele Daumerie'},
#  {'country': 'Italy', 'person': 'Anna Bongiorno'},
#  {'country': 'Kingdom of Italy', 'person': 'Anna Bongiorno'},
#  {'country': 'France', 'person': 'A. (Anna) François'},
#  {'country': 'France', 'person': 'Suzanne François'},
#  {'country': 'Germany', 'person': 'Hanne-Lore Friedrich'},
#  {'country': 'United States of America', 'person': 'Susan Kander'},
#  {'country': 'France', 'person': 'Dinah Douieb'},
#  {'country': 'Tunisia', 'person': 'Dinah Douieb'},
#  {'country': 'Norway', 'person': 'Signe Irene Time'},
#  {'country': 'France', 'person': 'Françoise Vacher'},
#  {'country': 'United Kingdom', 'person': 'Dorothy Pilling'},
#  {'country': 'United States of America', 'person': 'Lita Grier'},
#  {'country': 'Georgia', 'person': 'Dali Chkheidze'},
#  {'country': 'Soviet Union', 'person': 'Dali Chkheidze'},
#  {'country': 'Poland', 'person': 'Monika Brewczak'},
#  {'country': 'Portugal', 'person': 'Delfina Figueiredo'},
#  {'country': 'Hungary', 'person': 'Edit Szigeti'},
#  {'country': 'Ukraine', 'person': 'Q113465265'},
#  {'country': 'Argentina', 'person': 'Karina Vismara'},
#  {'country': 'France', 'person': 'Marie-Caroline Drummond de Melfort'},
#  {'country': 'Peru', 'person': 'Milena Warthon'},
#  {'country': 'Belgium', 'person': 'Guilhelmine Sabatier'},
#  {'country': 'United States of America', 'person': 'Madelyn Sheppard'},
#  {'country': 'France', 'person': 'Alice Gabeaud'},
#  {'country': 'France', 'person': 'Sally Galet'},
#  {'country': 'United Kingdom', 'person': 'Sally Galet'},
#  {'country': 'France', 'person': 'Sophie Gentils'},
#  {'country': 'United States of America', 'person': 'Nancy Gifford'},
#  {'country': 'United States of America', 'person': 'Ellen Gilson Voth'},
#  {'country': 'Switzerland', 'person': 'Franziska Gohl'},
#  {'country': 'United States of America', 'person': 'Lindsay Goodson'},
#  {'country': 'France', 'person': 'Louise-Zoé Gouirand-Gentil'},
#  {'country': 'France', 'person': 'Suzanne Goury'},
#  {'country': 'France', 'person': 'Anne Goyen'},
#  {'country': 'United States of America', 'person': 'Cynthia Gray'},
#  {'country': 'Sweden', 'person': 'Alida Grönlund'},
#  {'country': 'Norway', 'person': 'Anne Hilde Grov'},
#  {'country': 'France', 'person': 'Marthe Grumbach'},
#  {'country': 'United States of America', 'person': 'Nancy Grundahl'},
#  {'country': 'Austria-Hungary', 'person': 'Marija Berden'},
#  {'country': 'Kingdom of Serbs, Croats and Slovenes',
#   'person': 'Marija Berden'},
#  {'country': 'France', 'person': 'Ines Halimi'},
#  {'country': 'United Kingdom', 'person': 'Beatrice Mary Hall'},
#  {'country': 'France', 'person': 'Mylene Halsberghe'},
#  {'country': 'Canada', 'person': 'Corlynn Hanney'},
#  {'country': 'Poland', 'person': 'Ewa Fabiańska-Jelińska'},
#  {'country': 'Germany', 'person': 'Marianne Bellenhaus'},
#  {'country': 'Germany', 'person': 'Arunga Heiden'},
#  {'country': 'Germany', 'person': 'Eva-Maria Leeb'},
#  {'country': 'Canada', 'person': 'Stella Dupré'},
#  {'country': 'Kingdom of the Netherlands', 'person': 'Zoë Tauran'},
#  {'country': 'Kingdom of the Netherlands', 'person': 'Zoë Tauran'},
#  {'country': 'Hungary', 'person': 'Veronika Ágnes Fáncsik'},
#  {'country': 'Austria', 'person': 'Hilde Kuczor'},
#  {'country': 'Cisleithania', 'person': 'Hilde Kuczor'},
#  {'country': 'Switzerland', 'person': 'Maria Bonzanigo'},
#  {'country': 'Austria', 'person': 'Sophie Zapletal'},
#  {'country': 'Cisleithania', 'person': 'Sophie Zapletal'},
#  {'country': 'Spain', 'person': 'Maria Infiesta i Argüeso'},
#  {'country': 'Austria', 'person': 'Louise Ziegler'},
#  {'country': 'Cisleithania', 'person': 'Louise Ziegler'},
#  {'country': 'Austria', 'person': 'Maria Quell'},
#  {'country': 'Cisleithania', 'person': 'Maria Quell'},
#  {'country': "People's Republic of China", 'person': 'Zhong Wanyun'},
#  {'country': 'France', 'person': 'Juliette Dantin'},
#  {'country': 'Denmark', 'person': 'Selina Gin'},
#  {'country': 'Austria', 'person': 'Veronika Eberhart'},
#  {'country': 'Switzerland', 'person': 'Irene Hausammann'},
#  {'country': 'Switzerland', 'person': 'Irene Hausammann'},
#  {'country': 'Sweden', 'person': 'Irya Gmeyner'},
#  {'country': 'France', 'person': 'Yvonne Hédoux'},
#  {'country': 'United States of America', 'person': 'Marjan Helms'},
#  {'country': 'France', 'person': 'Françoise Herr'},
#  {'country': 'France', 'person': 'Camille Him'},
#  {'country': 'Australia', 'person': 'Sarah Hopkins'},
#  {'country': 'United States of America', 'person': 'Melanie Horne'},
#  {'country': 'France', 'person': 'Alice Hutin'},
#  {'country': 'Switzerland', 'person': 'Ruth Jacquemart'},
#  {'country': 'India', 'person': 'Ananya Chakraborty'},
#  {'country': 'France', 'person': 'Eliane Zurfluh'},
#  {'country': 'Austria', 'person': 'Emma Fischer'},
#  {'country': 'Cisleithania', 'person': 'Emma Fischer'},
#  {'country': 'Habsburg monarchy', 'person': 'Leopoldine Goubau d’Hovorst'},
#  {'country': 'Austria', 'person': 'Tona von Hermann'},
#  {'country': 'Cisleithania', 'person': 'Tona von Hermann'},
#  {'country': 'Austria', 'person': 'Kläre Hoschek-Mühlheim'},
#  {'country': 'Cisleithania', 'person': 'Kläre Hoschek-Mühlheim'},
#  {'country': 'South Korea', 'person': 'Eunyoung Kim'},
#  {'country': 'Germany', 'person': 'Marie König'},
#  {'country': 'Soviet Union', 'person': 'Q111499435'},
#  {'country': 'Russian Empire', 'person': 'Q111499435'},
#  {'country': 'United States of America', 'person': 'Belinda Reynolds'},
#  {'country': 'United States of America', 'person': 'Stella Sung'},
#  {'country': 'United States of America', 'person': 'Stella Sung'},
#  {'country': 'United States of America', 'person': 'Stella Sung'},
#  {'country': 'United States of America', 'person': 'Else Cellarius'},
#  {'country': 'Belarus', 'person': 'Larysa I. Simakovič'},
#  {'country': 'Ecuador', 'person': 'Rosa Jerves de Ordóñez'},
#  {'country': 'United States of America', 'person': 'Daisy Wood Hildreth'},
#  {'country': 'Poland', 'person': 'Barbara Kaszuba'},
#  {'country': 'Belgium', 'person': 'Irène Fuerison'},
#  {'country': 'United States of America', 'person': 'Leah Reid'},
#  {'country': 'United States of America', 'person': 'Kathryn Mishell'},
#  {'country': 'Brazil', 'person': 'Cris Lima'},
#  {'country': 'Brazil', 'person': 'Jadsa'},
#  {'country': 'United Kingdom', 'person': 'Trish Clowes'},
#  {'country': 'Argentina', 'person': 'Lucía Caruso'},
#  {'country': 'United States of America', 'person': 'Isobel Stone'},
#  {'country': 'Iran', 'person': 'Fojan Gharibnejad'},
#  {'country': 'Spain', 'person': 'Concha Monrás'},
#  {'country': 'Russia', 'person': 'Q111995677'},
#  {'country': 'Soviet Union', 'person': 'Q111995677'},
#  {'country': 'South Korea', 'person': 'Kim Ye-ji'},
#  {'country': 'Italy', 'person': 'Elena Cammarone'},
#  {'country': 'Finland', 'person': 'Säde Bartling'},
#  {'country': 'Estonia', 'person': 'Maria Mölder'},
#  {'country': 'United States of America', 'person': 'Leighton Barber'},
#  {'country': 'Ukraine', 'person': 'Q112127174'},
#  {'country': 'France', 'person': 'Fanny Roland'},
#  {'country': 'Algeria', 'person': 'Nadia Boumerdassi'},
#  {'country': 'Estonia', 'person': 'Elis Hallik'},
#  {'country': 'Japan', 'person': 'Moe Hyuga'},
#  {'country': 'Japan', 'person': 'Kana Hashiguchi'},
#  {'country': 'Morocco', 'person': 'Soukaina Fahsi'},
#  {'country': 'Spain', 'person': 'Paula Cendejas'},
#  {'country': 'Norway', 'person': 'Christine Hals'},
#  {'country': 'Sweden', 'person': 'Christine Hals'},
#  {'country': 'Canada', 'person': 'Elaine Kohama'},
#  {'country': 'France', 'person': 'Farnaz Modarresifar'},
#  {'country': 'Iran', 'person': 'Farnaz Modarresifar'},
#  {'country': 'Argentina', 'person': 'Eva Lopszyc'},
#  {'country': 'Armenian Soviet Socialist Republic', 'person': 'Q116215882'},
#  {'country': 'Armenia', 'person': 'Svetlana Aleksanyan'},
#  {'country': 'United States of America', 'person': 'Jamison Belushi'},
#  {'country': 'France', 'person': 'Paula Chabran'},
#  {'country': 'Armenia', 'person': 'Anna Azizyan'},
#  {'country': 'Armenian Soviet Socialist Republic', 'person': 'Anna Azizyan'},
#  {'country': 'Armenia', 'person': 'Jenny Asatryan'},
#  {'country': 'Argentina', 'person': 'Elvira Ceballos'},
#  {'country': 'Armenian Soviet Socialist Republic', 'person': 'Q116372294'},
#  {'country': 'United Kingdom', 'person': 'Q116382519'},
#  {'country': 'German Empire', 'person': 'Emilie Hensel'},
#  {'country': 'Argentina', 'person': 'Mila Manes'},
#  {'country': 'Sweden', 'person': 'Frida Johansson'},
#  {'country': 'United States of America', 'person': 'Maryam Khoury'},
#  {'country': 'United States of America', 'person': 'Susan LaBarr'},
#  {'country': 'France', 'person': 'Annie Labussiere'},
#  {'country': 'Russia', 'person': 'Q115203447'},
#  {'country': 'Brazil', 'person': 'Joana Batista Ramos'},
#  {'country': 'Ukraine', 'person': 'Mariia Kvitka'},
#  {'country': 'United States of America', 'person': 'Cat Ellington'},
#  {'country': 'Mexico', 'person': 'María del Refugio Ponce'},
#  {'country': 'United States of America', 'person': 'Gertrud Glauber'},
#  {'country': 'Austria', 'person': 'Gertrud Glauber'},
#  {'country': 'Cisleithania', 'person': 'Gertrud Glauber'},
#  {'country': 'Russia', 'person': 'Q115522015'},
#  {'country': 'Soviet Union', 'person': 'Q115522015'},
#  {'country': 'Portugal', 'person': 'Cristiana Kopke'},
#  {'country': 'Lithuania', 'person': 'Ieva Dūdaitė'},
#  {'country': 'Bolivia', 'person': 'Gaby Ferreyra'},
#  {'country': 'Suriname', 'person': 'Liesbeth Peroti'},
#  {'country': 'United States of America', 'person': 'Andromeda Turre'},
#  {'country': 'Portugal', 'person': 'Adelaide Saguer'},
#  {'country': 'South Korea', 'person': 'Sun-Mi Hong'},
#  {'country': 'Portugal', 'person': 'Patrícia Sucena de Almeida'},
#  {'country': 'Spain', 'person': 'Yoly Saa'},
#  {'country': 'France', 'person': 'Gabrielle Lange-Clairny'},
#  {'country': 'France', 'person': 'Caroline Martainville'},
#  {'country': 'Belgium', 'person': 'Therese Van den Staepele-Van Mechelen'},
#  {'country': 'United States of America', 'person': 'Lola Phinney'},
#  {'country': 'France', 'person': 'n 00114848'},
#  {'country': 'Cisleithania', 'person': 'Elsa Wellner'},
#  {'country': 'France', 'person': 'Mme Sounier-Geoffroy'},
#  {'country': 'France', 'person': 'Alice Pelliot'},
#  {'country': 'Spain', 'person': 'Q114895035'},
#  {'country': 'Kingdom of the Netherlands', 'person': 'Rikki Borgelt'},
#  {'country': 'Poland', 'person': 'Aleksandra Słyż'},
#  {'country': 'Azerbaijan', 'person': 'Ulviyya Kazimova'},
#  {'country': 'United States of America', 'person': 'Catherine Yi-yu Cho Woo'}]

# %%
import matplotlib.pyplot as plt

# Read the cleaned data from the JSON file
with open("cleaned_data.json", "r") as json_file:
    cleaned_data = json.load(json_file)

# Create a dictionary to store the count of each country
count_by_country = {}

# Iterate through the cleaned data and count the occurrences of each country
for item in cleaned_data:
    country = item['country']
    if country in count_by_country:
        count_by_country[country] += 1
    else:
        count_by_country[country] = 1

# Define a threshold for the number of occurrences
threshold = 400

# Create a dictionary to store the countries that meet the threshold
countries_above_threshold = {
    country: count for country, count in count_by_country.items() if count >= threshold
}

# Create the bar chart
plt.bar(countries_above_threshold.keys(), countries_above_threshold.values())
plt.xlabel("Country")
plt.ylabel("Count")
plt.title("Female composers by country")

# Show the chart
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [17], in <cell line: 24>()
#      29 image = result['image']['value']
#      30 # get the coordinates of the countries
# ---> 31 country_url = f'https://www.wikidata.org/w/api.php?action=wbgetentities&ids={result["country"]["value"].split("/")[-1]}&format=json'
#      32 coordinates = requests.get(country_url).json()["entities"][result["country"]["value"].split("/")[-1]]["claims"]["P625"][0]["mainsnak"]["datavalue"]["value"]
#      33 cleaned_data.append({"person": person, "personLabel": personLabel, "countryLabel": countryLabel, "birthDate": birthDate, "image": image, "coordinates": coordinates})
#
# KeyError: 'country'

# %%
from SPARQLWrapper import SPARQLWrapper, JSON
import pprint as pp

wikidata_endpoint = "https://query.wikidata.org/bigdata/namespace/wdq/sparql"


my_SPARQL_query = """
SELECT ?person ?personLabel ?countryLabel ?birthDate

WHERE {
  # ?person wdt:P31 wd:Q5.
  # ?person wdt:P106/wdt:P279* wd:Q158852.
  # ?person wdt:P21 wd:Q6581072.
  # ?person wdt:P27 ?country.
  # ?person wdt:P569 ?birthDate.
 
          
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
}

"""

sparql_wd = SPARQLWrapper(wikidata_endpoint)
sparql_wd.setQuery(my_SPARQL_query)
sparql_wd.setReturnFormat(JSON)
geoResult = sparql_wd.query().convert()

# %%
import json

# Clean the data
results = geoResult['results']['bindings']
cleaned_data2 = {}
for result in results:
    person = result['person']['value']
    personLabel = result['personLabel']['value']
    birthDate = result['birthDate']['value']
    countryLabel = result['countryLabel']['value']
    if countryLabel not in cleaned_data2:
        cleaned_data2[countryLabel] = []
    cleaned_data2[countryLabel].append({"person": person, "personLabel": personLabel, "birthDate": birthDate})

# Create a JSON file
with open('data.json', 'w') as f:
    json.dump(cleaned_data2, f)
pp.pprint(cleaned_data2)
# Out:
# {'Afghanistan': [{'birthDate': '2003-01-01T00:00:00Z',
#                   'person': 'http://www.wikidata.org/entity/Q110028761',
#                   'personLabel': 'Shogufa Safi'},
#                  {'birthDate': '1997-01-01T00:00:00Z',
#                   'person': 'http://www.wikidata.org/entity/Q31819218',
#                   'personLabel': 'Negin Khpalwak'}],
#  'Argentina': [{'birthDate': '1917-01-05T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q2286704',
#                 'personLabel': 'Silvia Eisenstein'},
#                {'birthDate': '1934-07-01T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q2646991',
#                 'personLabel': 'Alicia Terzian'},
#                {'birthDate': '1943-04-20T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q26912658',
#                 'personLabel': 'Marta Varela'},
#                {'birthDate': '1934-06-04T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q61329359',
#                 'personLabel': 'Lučka Kralj Jerman'},
#                {'birthDate': '1938-08-19T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q42559060',
#                 'personLabel': 'Nelly Vuksic'},
#                {'birthDate': '1924-06-27T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q54800735',
#                 'personLabel': 'Ebe Bedrune'},
#                {'birthDate': '1956-01-01T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q116142615',
#                 'personLabel': 'Eva Lopszyc'},
#                {'birthDate': '1980-01-01T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q19629724',
#                 'personLabel': 'Mariana Florès'}],
#  'Armenia': [{'birthDate': '1946-10-29T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q4311337',
#               'personLabel': 'Svetlana Navasardyan'},
#              {'birthDate': '1963-03-28T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q51068968',
#               'personLabel': 'Sona Hovhannisyan'},
#              {'birthDate': '1969-03-25T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q55421048',
#               'personLabel': 'Vardouhi Minassian'},
#              {'birthDate': '1961-09-24T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q27653038',
#               'personLabel': 'Naira Gyurjinyan'},
#              {'birthDate': '1963-03-28T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q51068968',
#               'personLabel': 'Sona Hovhannisyan'}],
#  'Australia': [{'birthDate': '1961-03-02T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q273672',
#                 'personLabel': 'Simone Young'},
#                {'birthDate': '1960-07-29T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q2214143',
#                 'personLabel': 'Nicolette Fraillon'},
#                {'birthDate': '1972-01-01T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q7422414',
#                 'personLabel': 'Sarah Ioannides'},
#                {'birthDate': '1945-01-19T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q16106906',
#                 'personLabel': 'Judith Clingan'},
#                {'birthDate': '1965-05-22T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q16196153',
#                 'personLabel': 'Kathleen McGuire'},
#                {'birthDate': '1963-01-01T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q21553650',
#                 'personLabel': 'Lyn Williams'},
#                {'birthDate': '1979-12-13T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q6187149',
#                 'personLabel': 'Jessica Cottis'},
#                {'birthDate': '1985-01-01T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q105836191',
#                 'personLabel': 'Elena Schwarz'},
#                {'birthDate': '1940-07-04T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q33553960',
#                 'personLabel': 'Helen Quach'},
#                {'birthDate': '1883-11-22T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q55632078',
#                 'personLabel': 'Ruby Claudia Davy'},
#                {'birthDate': '1785-01-01T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q96939932',
#                 'personLabel': 'Catherine Fitzpatrick'}],
#  'Austria': [{'birthDate': '1960-03-13T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q271746',
#               'personLabel': 'Gal Rasché'},
#              {'birthDate': '1906-11-03T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q78905',
#               'personLabel': 'Alma Rosé'},
#              {'birthDate': '1969-08-11T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1234934',
#               'personLabel': 'Doina Fischer'},
#              {'birthDate': '1891-03-09T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1317807',
#               'personLabel': 'Frida Kern'},
#              {'birthDate': '1961-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1330185',
#               'personLabel': 'Elisabeth Pfeiler'},
#              {'birthDate': '1963-03-22T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1663444',
#               'personLabel': 'Ingrun Fussenegger'},
#              {'birthDate': '1965-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1083248',
#               'personLabel': 'Christina Pluhar'},
#              {'birthDate': '1959-01-15T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q2389118',
#               'personLabel': 'Regina Pitscheneder'},
#              {'birthDate': '1957-04-22T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1931218',
#               'personLabel': 'Michi Gaigg'},
#              {'birthDate': '1980-04-22T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q15122546',
#               'personLabel': 'Nazanin Aghakhani'},
#              {'birthDate': '1976-03-08T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q15304732',
#               'personLabel': 'Elisabeth Fuchs'},
#              {'birthDate': '1944-04-24T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q4150327',
#               'personLabel': 'Agnes Grossmann'},
#              {'birthDate': '1973-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q60716925',
#               'personLabel': 'Maria Wolfsberger'},
#              {'birthDate': '1894-05-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q63479856',
#               'personLabel': 'Ida Fischer-Colbrie'},
#              {'birthDate': '1959-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q85113480',
#               'personLabel': 'Pei-Yu Chang'},
#              {'birthDate': '1968-07-12T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q98635515',
#               'personLabel': 'Elisabeth Attl'},
#              {'birthDate': '1993-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q111519703',
#               'personLabel': 'Clara Maria Bauer'},
#              {'birthDate': '1990-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q88961165',
#               'personLabel': 'Sigrid Horn'},
#              {'birthDate': '1965-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1083248',
#               'personLabel': 'Christina Pluhar'},
#              {'birthDate': '1961-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1330185',
#               'personLabel': 'Elisabeth Pfeiler'},
#              {'birthDate': '1923-02-22T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1546055',
#               'personLabel': 'Gretl Komposch'},
#              {'birthDate': '1951-05-10T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1593267',
#               'personLabel': 'Hedi Preissegger'},
#              {'birthDate': '1963-03-22T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1663444',
#               'personLabel': 'Ingrun Fussenegger'}],
#  'Austria-Hungary': [{'birthDate': '1915-01-14T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q263208',
#                       'personLabel': 'Vítězslava Kaprálová'},
#                      {'birthDate': '1915-01-24T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q263208',
#                       'personLabel': 'Vítězslava Kaprálová'},
#                      {'birthDate': '1888-02-16T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q4380347',
#                       'personLabel': 'Ludmila Prokopová'},
#                      {'birthDate': '1888-02-26T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q4380347',
#                       'personLabel': 'Ludmila Prokopová'},
#                      {'birthDate': '1892-02-26T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q4380347',
#                       'personLabel': 'Ludmila Prokopová'},
#                      {'birthDate': '1894-03-15T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q7542456',
#                       'personLabel': 'Sláva Vorlová'},
#                      {'birthDate': '1848-08-02T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q59653090',
#                       'personLabel': 'Josefine Amann-Weinlich'},
#                      {'birthDate': '1912-12-30T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q65936025',
#                       'personLabel': 'Peter Lipar'},
#                      {'birthDate': '1902-01-02T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q86972819',
#                       'personLabel': 'Q86972819'},
#                      {'birthDate': '1908-07-11T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q12775590',
#                       'personLabel': 'Ružena Polónyová-Žaludová'},
#                      {'birthDate': '1893-08-20T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q12786414',
#                       'personLabel': 'Breda Šček'},
#                      {'birthDate': '1893-01-01T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q63079921',
#                       'personLabel': 'Louisa Glückseligová-Pávová'}],
#  'Austrian Empire': [{'birthDate': '1848-08-02T00:00:00Z',
#                       'person': 'http://www.wikidata.org/entity/Q59653090',
#                       'personLabel': 'Josefine Amann-Weinlich'}],
#  'Azerbaijan': [{'birthDate': '1989-06-13T00:00:00Z',
#                  'person': 'http://www.wikidata.org/entity/Q16366466',
#                  'personLabel': 'Diana Hacıyeva'},
#                 {'birthDate': '1962-01-01T00:00:00Z',
#                  'person': 'http://www.wikidata.org/entity/Q5367014',
#                  'personLabel': 'Elnara Kerimova'},
#                 {'birthDate': '1933-08-03T00:00:00Z',
#                  'person': 'http://www.wikidata.org/entity/Q106043876',
#                  'personLabel': 'Q106043876'},
#                 {'birthDate': '1933-08-03T00:00:00Z',
#                  'person': 'http://www.wikidata.org/entity/Q106043876',
#                  'personLabel': 'Q106043876'},
#                 {'birthDate': '1975-04-23T00:00:00Z',
#                  'person': 'http://www.wikidata.org/entity/Q5702304',
#                  'personLabel': 'Sevil Haciyeva'}],
#  'Belarus': [{'birthDate': '1963-09-09T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q4297439',
#               'personLabel': 'Q4297439'},
#              {'birthDate': '1954-12-14T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q17462380',
#               'personLabel': 'Ala Ihumnava'},
#              {'birthDate': '1914-08-02T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q18243816',
#               'personLabel': 'Tatsyana Kalamiytsava'},
#              {'birthDate': '1923-01-16T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q4190280',
#               'personLabel': 'Hanna Zelyankova'},
#              {'birthDate': '1963-09-09T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q4297439',
#               'personLabel': 'Q4297439'},
#              {'birthDate': '1991-07-23T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q112302616',
#               'personLabel': 'Q112302616'}],
#  'Belgium': [{'birthDate': '1930-12-27T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q273031',
#               'personLabel': 'Jacqueline Fontyn'},
#              {'birthDate': '1986-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q2467138',
#               'personLabel': 'Liesa Van der Aa'},
#              {'birthDate': '1933-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1725879',
#               'personLabel': 'Monica Nève'},
#              {'birthDate': '1914-01-25T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q6294408',
#               'personLabel': 'Josée Vigneron-Ramackers'},
#              {'birthDate': '1902-07-20T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q15434443',
#               'personLabel': 'Rose Thisse-Derouette'},
#              {'birthDate': '1870-01-05T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q5408593',
#               'personLabel': 'Eugénie-Emilie Juliette Folville'},
#              {'birthDate': '1903-09-26T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q5506733',
#               'personLabel': 'Frédérique Petrides'}],
#  'Bolivia': [{'birthDate': '1981-09-27T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q5995548',
#               'personLabel': 'Marcela Tórrez Sahonero'}],
#  'Brazil': [{'birthDate': '1847-10-17T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q465902',
#              'personLabel': 'Chiquinha Gonzaga'},
#             {'birthDate': '1959-10-07T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q1328957',
#              'personLabel': 'Eliane'},
#             {'birthDate': '1953-01-01T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q3020840',
#              'personLabel': 'Debora Waldman'},
#             {'birthDate': '1914-05-18T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q5016032',
#              'personLabel': 'Cacilda Borges Barbosa'},
#             {'birthDate': '1964-08-21T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q6546651',
#              'personLabel': 'Ligia Amadio'},
#             {'birthDate': '1910-02-18T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q6707279',
#              'personLabel': 'Lycia de Biase Bidart'},
#             {'birthDate': '1951-12-01T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q6778285',
#              'personLabel': 'Myrna Herzog'},
#             {'birthDate': '1915-09-25T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q6960012',
#              'personLabel': 'Najla Jabor'},
#             {'birthDate': '1926-09-28T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q5401299',
#              'personLabel': 'Esther Scliar'},
#             {'birthDate': '1977-01-22T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q32534495',
#              'personLabel': 'Simone Menezes'},
#             {'birthDate': '1987-05-25T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q20048170',
#              'personLabel': 'Luedji Luna'},
#             {'birthDate': '1955-05-31T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q48872746',
#              'personLabel': 'Naomi Munakata'},
#             {'birthDate': '1964-09-16T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q20048427',
#              'personLabel': 'Valéria Lobão'}],
#  'British Hong Kong': [{'birthDate': '1987-01-01T00:00:00Z',
#                         'person': 'http://www.wikidata.org/entity/Q107155135',
#                         'personLabel': 'Jamie Man'}],
#  'Bulgaria': [{'birthDate': '1888-02-16T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q4380347',
#                'personLabel': 'Ludmila Prokopová'},
#               {'birthDate': '1888-02-26T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q4380347',
#                'personLabel': 'Ludmila Prokopová'},
#               {'birthDate': '1892-02-26T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q4380347',
#                'personLabel': 'Ludmila Prokopová'},
#               {'birthDate': '1947-03-01T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q12279041',
#                'personLabel': 'Dora Hristova'},
#               {'birthDate': '1942-09-24T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q12280523',
#                'personLabel': 'Zlatina Deliradeva'},
#               {'birthDate': '1924-04-12T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q12284901',
#                'personLabel': 'Lilyana Bocheva'},
#               {'birthDate': '1930-09-03T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q12292567',
#                'personLabel': 'Rositsa Batalova'},
#               {'birthDate': '1948-05-06T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q12293283',
#                'personLabel': 'Svetla Beshovishka'},
#               {'birthDate': '1938-09-22T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q12295352',
#                'personLabel': 'Stefka Blagoeva'},
#               {'birthDate': '1939-09-28T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q19204680',
#                'personLabel': 'Petya Pavlovich'},
#               {'birthDate': '1980-03-21T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q19964512',
#                'personLabel': 'Diliana Michailov'},
#               {'birthDate': '1961-10-14T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q24663099',
#                'personLabel': 'Veneziela Naydenova'},
#               {'birthDate': '1933-01-05T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q75930223',
#                'personLabel': 'Liliya Gyuleva'},
#               {'birthDate': '1983-01-01T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q108039694',
#                'personLabel': 'Zefira Valova'},
#               {'birthDate': '1981-05-18T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q58038441',
#                'personLabel': 'Sonya Chakarova'},
#               {'birthDate': '1942-09-24T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q12280523',
#                'personLabel': 'Zlatina Deliradeva'},
#               {'birthDate': '1924-04-12T00:00:00Z',
#                'person': 'http://www.wikidata.org/entity/Q12284901',
#                'personLabel': 'Lilyana Bocheva'}],
#  'Canada': [{'birthDate': '1910-08-25T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q448933',
#              'personLabel': 'Ethel Stark'},
#             {'birthDate': '1916-08-25T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q448933',
#              'personLabel': 'Ethel Stark'},
#             {'birthDate': '1949-08-14T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q539291',
#              'personLabel': 'Jeanne Lamon'},
#             {'birthDate': '1943-07-28T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q2851162',
#              'personLabel': 'Anne Lauber'},
#             {'birthDate': '1957-05-21T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q3241322',
#              'personLabel': 'Linda Bouchard'},
#             {'birthDate': '1947-09-23T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q3259665',
#              'personLabel': 'Lorraine Vaillancourt'},
#             {'birthDate': '1971-05-08T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q4495517',
#              'personLabel': 'Barbara Hannigan'},
#             {'birthDate': '1955-04-21T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q4669232',
#              'personLabel': 'Eleanor Joanne Daley'},
#             {'birthDate': '1930-12-12T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q4765639',
#              'personLabel': 'Anita Sleeman'},
#             {'birthDate': '1972-03-17T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q6306350',
#              'personLabel': 'Julia Davids'},
#             {'birthDate': '1967-05-17T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q6393866',
#              'personLabel': 'Keri-Lynn Wilson'},
#             {'birthDate': '1950-05-08T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q6963034',
#              'personLabel': 'Nancy Telfer'},
#             {'birthDate': '1968-11-22T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q7422550',
#              'personLabel': 'Sarah MacDonald'},
#             {'birthDate': '1989-12-29T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q16734835',
#              'personLabel': 'Rachel Mahon'},
#             {'birthDate': '1928-03-08T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q16958474',
#              'personLabel': 'Jacqueline Richard'},
#             {'birthDate': '1963-01-01T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q3564321',
#              'personLabel': 'Véronique Lacroix'},
#             {'birthDate': '1947-03-07T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q6170142',
#              'personLabel': 'Jean Ashworth Bartle'},
#             {'birthDate': '1984-11-20T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q95751962',
#              'personLabel': 'Dina Gilbert'},
#             {'birthDate': '1989-01-01T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q63285863',
#              'personLabel': 'Kathleen Allan'},
#             {'birthDate': '1902-01-02T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q86972819',
#              'personLabel': 'Q86972819'},
#             {'birthDate': '1923-05-20T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q107230845',
#              'personLabel': 'Q107230845'},
#             {'birthDate': '1894-12-07T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q56260895',
#              'personLabel': 'Anne Benn'},
#             {'birthDate': '1930-06-28T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q15436252',
#              'personLabel': 'Winnifred Sim'},
#             {'birthDate': '1970-12-29T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q4081886',
#              'personLabel': 'Marie-Annick Béliveau'},
#             {'birthDate': '1955-04-21T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q4669232',
#              'personLabel': 'Eleanor Joanne Daley'},
#             {'birthDate': '1849-12-25T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q7351502',
#              'personLabel': 'Roberta Geddes-Harvey'},
#             {'birthDate': '1989-12-29T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q16734835',
#              'personLabel': 'Rachel Mahon'},
#             {'birthDate': '1960-12-29T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q55064945',
#              'personLabel': 'Ramona Luengen'},
#             {'birthDate': '1929-01-01T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q55096311',
#              'personLabel': 'Patricia Rolston'},
#             {'birthDate': '1928-02-29T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q55825667',
#              'personLabel': 'Edna Little'},
#             {'birthDate': '1903-06-02T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q56260354',
#              'personLabel': 'Ria Lenssens'},
#             {'birthDate': '1928-11-10T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q56479110',
#              'personLabel': 'Diane Oxner'},
#             {'birthDate': '1943-03-02T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q56653827',
#              'personLabel': 'Deirdre Piper'},
#             {'birthDate': '1960-09-28T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q106304836',
#              'personLabel': 'Elizabeth MacIsaac'},
#             {'birthDate': '1979-01-01T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q111455318',
#              'personLabel': 'Geneviève Jodoin'},
#             {'birthDate': '1912-01-16T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q61163140',
#              'personLabel': 'Anne Campbell'},
#             {'birthDate': '1937-10-24T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q70119430',
#              'personLabel': 'Chantal Masson Bourque'}],
#  'Chile': [{'birthDate': '1975-10-02T00:00:00Z',
#             'person': 'http://www.wikidata.org/entity/Q96621277',
#             'personLabel': 'Alejandra Urrutia'}],
#  'Cisleithania': [{'birthDate': '1906-06-19T00:00:00Z',
#                    'person': 'http://www.wikidata.org/entity/Q114050616',
#                    'personLabel': 'Justina Trobina'}],
#  'Costa Rica': [{'birthDate': '1900-05-16T00:00:00Z',
#                  'person': 'http://www.wikidata.org/entity/Q6668808',
#                  'personLabel': 'Lola Castegnaro'}],
#  'Croatia': [{'birthDate': '1905-06-13T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q2118258',
#               'personLabel': 'Ivana Fišer'}],
#  'Cuba': [{'birthDate': '1943-05-14T00:00:00Z',
#            'person': 'http://www.wikidata.org/entity/Q463308',
#            'personLabel': 'Tania León'},
#           {'birthDate': '1924-12-21T00:00:00Z',
#            'person': 'http://www.wikidata.org/entity/Q4696633',
#            'personLabel': 'Aida Diestro'},
#           {'birthDate': '1949-10-31T00:00:00Z',
#            'person': 'http://www.wikidata.org/entity/Q7077256',
#            'personLabel': 'Odaline de la Martinez'},
#           {'birthDate': '1948-08-15T00:00:00Z',
#            'person': 'http://www.wikidata.org/entity/Q55941186',
#            'personLabel': 'Elena Herrera Peraza'},
#           {'birthDate': '1952-12-04T00:00:00Z',
#            'person': 'http://www.wikidata.org/entity/Q55961799',
#            'personLabel': 'Zenaida Castro Romeu'},
#           {'birthDate': '1988-05-16T00:00:00Z',
#            'person': 'http://www.wikidata.org/entity/Q20925615',
#            'personLabel': 'Wilma Alba Cal'},
#           {'birthDate': '1912-09-15T00:00:00Z',
#            'person': 'http://www.wikidata.org/entity/Q545305',
#            'personLabel': 'Gisela Hernández'},
#           {'birthDate': '1947-09-16T00:00:00Z',
#            'person': 'http://www.wikidata.org/entity/Q69580253',
#            'personLabel': 'Hilda Elvira Santiago Novo'}],
#  'Cyprus': [{'birthDate': '1981-04-24T00:00:00Z',
#              'person': 'http://www.wikidata.org/entity/Q84438734',
#              'personLabel': 'Christina Athinodorou'}],
#  'Czech Republic': [{'birthDate': '1973-01-01T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q6763419',
#                      'personLabel': 'Marika Pečená'},
#                     {'birthDate': '1981-06-01T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q15980410',
#                      'personLabel': 'Zuzana Kadlčíková'},
#                     {'birthDate': '1935-06-10T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q18745752',
#                      'personLabel': 'Alena Husková'},
#                     {'birthDate': '1983-09-22T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q24576475',
#                      'personLabel': 'Linda Keprtová'},
#                     {'birthDate': '1982-04-21T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q26927217',
#                      'personLabel': 'Valentina Shuklina'},
#                     {'birthDate': '1979-04-04T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q12019437',
#                      'personLabel': 'Helena Velická'},
#                     {'birthDate': '1961-08-02T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q70726464',
#                      'personLabel': 'Miriam Nemcova'},
#                     {'birthDate': '1960-02-15T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q13211577',
#                      'personLabel': 'Lenka Halamová'},
#                     {'birthDate': '1943-09-13T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q13218449',
#                      'personLabel': 'Lydie Romanská'},
#                     {'birthDate': '1979-04-04T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q12019437',
#                      'personLabel': 'Helena Velická'},
#                     {'birthDate': '1959-05-26T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q30531169',
#                      'personLabel': 'Lydie Härtelová'},
#                     {'birthDate': '1988-09-18T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q106098298',
#                      'personLabel': 'Pavlína Váchová'},
#                     {'birthDate': '1950-12-26T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q107643488',
#                      'personLabel': 'Růžena Saligerová'},
#                     {'birthDate': '1975-10-17T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q111029800',
#                      'personLabel': 'Olga Holoubková'},
#                     {'birthDate': '1935-01-11T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q65924889',
#                      'personLabel': 'Blanka Kulínská'}],
#  'Czechoslovakia': [{'birthDate': '1915-01-14T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q263208',
#                      'personLabel': 'Vítězslava Kaprálová'},
#                     {'birthDate': '1915-01-24T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q263208',
#                      'personLabel': 'Vítězslava Kaprálová'},
#                     {'birthDate': '1894-03-15T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q7542456',
#                      'personLabel': 'Sláva Vorlová'},
#                     {'birthDate': '1895-03-28T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q18564383',
#                      'personLabel': 'Anna Polmanová-Preclíková'},
#                     {'birthDate': '1880-11-25T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q95103989',
#                      'personLabel': 'Růžena Valentová'},
#                     {'birthDate': '1917-12-24T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q95145538',
#                      'personLabel': 'Jarmila Bartejsová'},
#                     {'birthDate': '1896-02-20T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q95146404',
#                      'personLabel': 'Marie Kučerová-Herbstová'},
#                     {'birthDate': '1928-06-25T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q95395503',
#                      'personLabel': 'Hana Schillerová'},
#                     {'birthDate': '1908-07-11T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q12775590',
#                      'personLabel': 'Ružena Polónyová-Žaludová'},
#                     {'birthDate': '1932-07-18T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q95484670',
#                      'personLabel': 'Ilona Vilímcová'},
#                     {'birthDate': '1910-07-03T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q105720848',
#                      'personLabel': 'Olga Dutková'},
#                     {'birthDate': '1950-12-26T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q107643488',
#                      'personLabel': 'Růžena Saligerová'},
#                     {'birthDate': '1975-10-17T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q111029800',
#                      'personLabel': 'Olga Holoubková'},
#                     {'birthDate': '1893-01-01T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q63079921',
#                      'personLabel': 'Louisa Glückseligová-Pávová'},
#                     {'birthDate': '1935-01-11T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q65924889',
#                      'personLabel': 'Blanka Kulínská'},
#                     {'birthDate': '1917-12-24T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q95145538',
#                      'personLabel': 'Jarmila Bartejsová'},
#                     {'birthDate': '1935-11-17T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q95147523',
#                      'personLabel': 'Jaroslava Modrochová'},
#                     {'birthDate': '1901-04-28T00:00:00Z',
#                      'person': 'http://www.wikidata.org/entity/Q95176351',
#                      'personLabel': 'Zora Zemanová'}],
#  'Denmark': [{'birthDate': '1910-12-12T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12314304',
#               'personLabel': 'Grethe Kolbe'},
#              {'birthDate': '1982-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16197882',
#               'personLabel': 'Maria Badstue'},
#              {'birthDate': '1947-12-25T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q18082124',
#               'personLabel': 'Marianne Clausen'},
#              {'birthDate': '1860-09-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q18759120',
#               'personLabel': 'Fanny Gætje'},
#              {'birthDate': '1906-08-23T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q62080885',
#               'personLabel': 'Liselotte Selbiger'},
#              {'birthDate': '1952-02-26T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12303963',
#               'personLabel': 'Bodil Heister'},
#              {'birthDate': '1966-04-13T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q23661749',
#               'personLabel': 'Pernille Bévort'},
#              {'birthDate': '1984-04-19T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q55519348',
#               'personLabel': 'Kathrine Windfeld'},
#              {'birthDate': '1973-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12327345',
#               'personLabel': 'Miriam Jul'},
#              {'birthDate': '1947-12-25T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q18082124',
#               'personLabel': 'Marianne Clausen'}],
#  'Dominican Republic': [{'birthDate': '1914-01-01T00:00:00Z',
#                          'person': 'http://www.wikidata.org/entity/Q63214861',
#                          'personLabel': 'Monina Cámpora'}],
#  'Estonia': [{'birthDate': '1864-02-09T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q438792',
#               'personLabel': 'Miina Härma'},
#              {'birthDate': '1969-04-15T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q544411',
#               'personLabel': 'Kaisa Roose'},
#              {'birthDate': '1972-06-18T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q468753',
#               'personLabel': 'Anu Tali'},
#              {'birthDate': '1978-07-12T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1572112',
#               'personLabel': 'Kristiina Poska'},
#              {'birthDate': '1907-05-17T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1825896',
#               'personLabel': 'Linda Saul'},
#              {'birthDate': '1976-07-23T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12365064',
#               'personLabel': 'Janne Fridolin'},
#              {'birthDate': '1974-06-17T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12368801',
#               'personLabel': 'Lilyan Kaiv'},
#              {'birthDate': '1948-01-09T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12369162',
#               'personLabel': 'Lydia Rahula'},
#              {'birthDate': '1981-09-08T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12375108',
#               'personLabel': 'Sirly Illak'},
#              {'birthDate': '1953-01-05T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12377846',
#               'personLabel': 'Urve Uusberg'},
#              {'birthDate': '1980-11-27T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q7922522',
#               'personLabel': 'Veronika Portsmuth'},
#              {'birthDate': '1926-11-06T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16403128',
#               'personLabel': 'Heli Martin'},
#              {'birthDate': '1933-11-07T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16403976',
#               'personLabel': 'Irina Anniko'},
#              {'birthDate': '1966-11-09T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16404639',
#               'personLabel': 'Annely Kuningas'},
#              {'birthDate': '1968-03-16T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16405151',
#               'personLabel': 'Ingrid Kõrvits'},
#              {'birthDate': '1972-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16405930',
#               'personLabel': 'Kadri Tali'},
#              {'birthDate': '1953-03-23T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16406299',
#               'personLabel': 'Kadri Leppoja'},
#              {'birthDate': '1924-12-03T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16407346',
#               'personLabel': 'Ira Trilljärv'},
#              {'birthDate': '1946-07-04T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16407533',
#               'personLabel': 'Lehte Aava'},
#              {'birthDate': '1979-04-18T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q14437341',
#               'personLabel': 'Maria Faust'},
#              {'birthDate': '1933-12-19T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q3528377',
#               'personLabel': 'Tiia-Ester Loitme'},
#              {'birthDate': '1986-04-21T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q61109901',
#               'personLabel': 'Jaanika Kuusik'},
#              {'birthDate': '1963-11-23T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q61111194',
#               'personLabel': 'Elo Üleoja'},
#              {'birthDate': '1975-08-19T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q42900521',
#               'personLabel': 'Kaie Tanner'},
#              {'birthDate': '1913-12-16T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q48645138',
#               'personLabel': 'Aasa Ellerhein'},
#              {'birthDate': '1986-11-18T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q18753401',
#               'personLabel': 'Kadri Voorand'},
#              {'birthDate': '1979-04-18T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q14437341',
#               'personLabel': 'Maria Faust'},
#              {'birthDate': '1933-12-19T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q3528377',
#               'personLabel': 'Tiia-Ester Loitme'},
#              {'birthDate': '1980-11-27T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q7922522',
#               'personLabel': 'Veronika Portsmuth'},
#              {'birthDate': '1958-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12359295',
#               'personLabel': 'Anne Pääsuke'},
#              {'birthDate': '1966-01-14T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12359300',
#               'personLabel': 'Anne Uusna'},
#              {'birthDate': '1961-04-29T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12359308',
#               'personLabel': 'Annelii Traks'},
#              {'birthDate': '1976-07-23T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12365064',
#               'personLabel': 'Janne Fridolin'},
#              {'birthDate': '1968-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12366352',
#               'personLabel': 'Karin Veissmann'},
#              {'birthDate': '1963-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12367698',
#               'personLabel': 'Kulla Aavik'},
#              {'birthDate': '1974-06-17T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12368801',
#               'personLabel': 'Lilyan Kaiv'},
#              {'birthDate': '1948-01-09T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12369162',
#               'personLabel': 'Lydia Rahula'},
#              {'birthDate': '1950-06-26T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12370168',
#               'personLabel': 'Merike Aarma'},
#              {'birthDate': '1950-06-28T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12370168',
#               'personLabel': 'Merike Aarma'},
#              {'birthDate': '1975-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12377245',
#               'personLabel': 'Triin Koch'},
#              {'birthDate': '1966-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12377439',
#               'personLabel': 'Tuuliki Jürjo'},
#              {'birthDate': '1940-05-11T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q12377997',
#               'personLabel': 'Vaike Uibopuu'},
#              {'birthDate': '1926-11-06T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16403128',
#               'personLabel': 'Heli Martin'},
#              {'birthDate': '1969-04-29T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16404086',
#               'personLabel': 'Triin Ella'},
#              {'birthDate': '1966-11-09T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16404639',
#               'personLabel': 'Annely Kuningas'},
#              {'birthDate': '1969-05-09T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16405234',
#               'personLabel': 'Heli Jürgenson'},
#              {'birthDate': '1958-11-21T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16405438',
#               'personLabel': 'Sirje Kaasik'},
#              {'birthDate': '1965-03-28T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16405557',
#               'personLabel': 'Anneli Surva'},
#              {'birthDate': '1907-01-23T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16406472',
#               'personLabel': 'Tiiu Targama'},
#              {'birthDate': '1962-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16406709',
#               'personLabel': 'Thea Paluoja'},
#              {'birthDate': '1946-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16407228',
#               'personLabel': 'Ludmilla Toon'},
#              {'birthDate': '1946-07-04T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q16407533',
#               'personLabel': 'Lehte Aava'},
#              {'birthDate': '1937-08-26T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q17447394',
#               'personLabel': 'Ene Üleoja'},
#              {'birthDate': '1930-03-15T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q18752947',
#               'personLabel': 'Maimu-Koidula Sirel'},
#              {'birthDate': '1972-03-28T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q20528283',
#               'personLabel': 'Eva Kams'},
#              {'birthDate': '1926-05-10T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q20528313',
#               'personLabel': 'Laine Karindi'},
#              {'birthDate': '1910-05-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q20528669',
#               'personLabel': 'Alma Tamm'},
#              {'birthDate': '1881-01-31T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q23942705',
#               'personLabel': 'Salme Kann'},
#              {'birthDate': '1957-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q24545632',
#               'personLabel': 'Külli Lokko'},
#              {'birthDate': '1936-03-26T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q26720374',
#               'personLabel': 'Mare Erik'},
#              {'birthDate': '1957-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q29419908',
#               'personLabel': 'Tiina Luhamets'},
#              {'birthDate': '1947-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q29420044',
#               'personLabel': 'Linda Kardna'},
#              {'birthDate': '1942-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q29420329',
#               'personLabel': 'Anneli Mäeots'},
#              {'birthDate': '1907-09-18T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q29420363',
#               'personLabel': 'Regina Sokk'},
#              {'birthDate': '1986-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q40410835',
#               'personLabel': 'Tiiu Ivanova'},
#              {'birthDate': '1942-07-30T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q42348502',
#               'personLabel': 'Anne Dorbek'},
#              {'birthDate': '1941-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q42710990',
#               'personLabel': 'Anu Köbas'},
#              {'birthDate': '1933-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q42900577',
#               'personLabel': 'Silvia Mellik'},
#              {'birthDate': '1921-06-11T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q96233705',
#               'personLabel': 'Hella Tedder'},
#              {'birthDate': '1864-02-09T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q438792',
#               'personLabel': 'Miina Härma'},
#              {'birthDate': '1937-08-05T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q114796119',
#               'personLabel': 'Heli-Maria Kahu'}],
#  'Federal Republic of Yugoslavia': [{'birthDate': '1970-04-07T00:00:00Z',
#                                      'person': 'http://www.wikidata.org/entity/Q2469281',
#                                      'personLabel': 'Divna Ljubojević'}],
#  'Finland': [{'birthDate': '1969-03-13T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q2390288',
#               'personLabel': 'Susanna Mälkki'},
#              {'birthDate': '1982-01-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q4349651',
# ...
#                               {'birthDate': '1888-11-27T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q4733561',
#                                'personLabel': 'Alma Julia Hightower'},
#                               {'birthDate': '1913-08-13T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q4767267',
#                                'personLabel': 'Anna Mae Winburn'},
#                               {'birthDate': '1917-05-31T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q4911881',
#                                'personLabel': 'Billie Rogers'},
#                               {'birthDate': '1921-08-20T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q5571440',
#                                'personLabel': 'Gloria Parker'},
#                               {'birthDate': '1940-11-13T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q6153454',
#                                'personLabel': 'Janet Lawson'},
#                               {'birthDate': '1944-09-26T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q6304370',
#                                'personLabel': 'Judy Chamberlain'},
#                               {'birthDate': '1951-03-18T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q6417462',
#                                'personLabel': 'Kit McClure'},
#                               {'birthDate': '1923-02-27T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q6697277',
#                                'personLabel': 'Lucille Dixon Robertson'},
#                               {'birthDate': '1954-01-18T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q7807927',
#                                'personLabel': 'Tina Marsh'},
#                               {'birthDate': '1987-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q7975703',
#                                'personLabel': 'Waxahatchee'},
#                               {'birthDate': '1962-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q13569942',
#                                'personLabel': 'Cecilia Coleman'},
#                               {'birthDate': '1915-07-22T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q14930387',
#                                'personLabel': 'Ada Leonard'},
#                               {'birthDate': '1919-02-13T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q17486509',
#                                'personLabel': 'Evelyn Freeman Roberts'},
#                               {'birthDate': '1867-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q21998384',
#                                'personLabel': 'Helen May Butler'},
#                               {'birthDate': '1957-06-28T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q22003018',
#                                'personLabel': 'Annette A. Aguilar'},
#                               {'birthDate': '1914-04-07T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q51719289',
#                                'personLabel': 'Neliska Ann Briscoe'},
#                               {'birthDate': '1998-06-20T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q61867556',
#                                'personLabel': 'Sasha Berliner'},
#                               {'birthDate': '1941-01-14T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q107467501',
#                                'personLabel': 'JaFran Jones'},
#                               {'birthDate': '1905-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q15135301',
#                                'personLabel': 'Lorene Harrison'},
#                               {'birthDate': '1962-07-30T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q15785522',
#                                'personLabel': 'Barbara Sletto'},
#                               {'birthDate': '1957-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q6205481',
#                                'personLabel': 'Joan Szymko'},
#                               {'birthDate': '1921-01-17T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q6681344',
#                                'personLabel': 'Lorna Cooke deVaron'},
#                               {'birthDate': '1858-04-03T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q7607136',
#                                'personLabel': 'Stella Stocker'},
#                               {'birthDate': '1941-09-11T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q7680776',
#                                'personLabel': 'Tamara Brooks'},
#                               {'birthDate': '1965-08-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q7777210',
#                                'personLabel': 'Thea Kano'},
#                               {'birthDate': '1937-12-21T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q12787001',
#                                'personLabel': 'Cilka Dolgan-Valenčič'},
#                               {'birthDate': '1951-10-04T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q16148949',
#                                'personLabel': 'Mary Hopper'},
#                               {'birthDate': '1946-02-12T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q20069319',
#                                'personLabel': 'Lyudmyla Poryvay'},
#                               {'birthDate': '1948-01-29T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q24702437',
#                                'personLabel': 'Catherine Roma'},
#                               {'birthDate': '1875-08-31T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q43272852',
#                                'personLabel': 'Rosa Lemberg'},
#                               {'birthDate': '1881-05-03T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q52686602',
#                                'personLabel': 'Bertha Foster'},
#                               {'birthDate': '1939-01-19T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q95880886',
#                                'personLabel': 'Alice Louise Trout'},
#                               {'birthDate': '1946-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q95888000',
#                                'personLabel': 'Rhoda Hatch'},
#                               {'birthDate': '1888-01-18T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q96741673',
#                                'personLabel': 'Amy Aldrich Worth'},
#                               {'birthDate': '1896-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q98880763',
#                                'personLabel': 'Loretta Cessor Manggrum'},
#                               {'birthDate': '1896-07-28T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q98880763',
#                                'personLabel': 'Loretta Cessor Manggrum'},
#                               {'birthDate': '1969-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q99735842',
#                                'personLabel': 'Giselle Wyers'},
#                               {'birthDate': '1936-11-11T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q100978611',
#                                'personLabel': 'Carol Doran'},
#                               {'birthDate': '1971-08-17T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q100994151',
#                                'personLabel': 'Jennifer Rodgers'},
#                               {'birthDate': '1928-02-28T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q101552929',
#                                'personLabel': 'Ruth-Esther Hillilä'},
#                               {'birthDate': '1957-05-20T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q104177201',
#                                'personLabel': 'Laurie Cappello'},
#                               {'birthDate': '1962-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q104783393',
#                                'personLabel': 'Brenda Mohr'},
#                               {'birthDate': '1895-03-10T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q105801776',
#                                'personLabel': 'Mildred Lund Tyson'},
#                               {'birthDate': '1939-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q105837853',
#                                'personLabel': 'Betty Bertaux'},
#                               {'birthDate': '1948-01-06T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q106071343',
#                                'personLabel': 'Q106071343'},
#                               {'birthDate': '1981-02-12T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q106303294',
#                                'personLabel': 'Amanda Huntleigh'},
#                               {'birthDate': '1971-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q106814383',
#                                'personLabel': 'Hee Won Chung'},
#                               {'birthDate': '1987-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q106878281',
#                                'personLabel': 'Sarah Riskind'},
#                               {'birthDate': '1912-03-18T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q108923470',
#                                'personLabel': 'Nelsie Johnson'},
#                               {'birthDate': '1909-09-23T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q125664',
#                                'personLabel': 'Blanche Honegger Moyse'},
#                               {'birthDate': '1995-11-29T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q242792',
#                                'personLabel': 'Laura Marano'},
#                               {'birthDate': '2000-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q1044160',
#                                'personLabel': 'Carol Cymbala'},
#                               {'birthDate': '1895-01-20T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q1379244',
#                                'personLabel': 'Eva Jessye'},
#                               {'birthDate': '1885-01-04T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q65717900',
#                                'personLabel': 'Nellie Weldon Cocroft'},
#                               {'birthDate': '1885-11-04T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q65717900',
#                                'personLabel': 'Nellie Weldon Cocroft'},
#                               {'birthDate': '1892-01-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q94128702',
#                                'personLabel': 'Kathleen Munro'},
#                               {'birthDate': '1993-03-01T00:00:00Z',
#                                'person': 'http://www.wikidata.org/entity/Q113587223',
#                                'personLabel': 'Annie Zylstra'}],
#  'Uruguay': [{'birthDate': '1954-03-01T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q1140394',
#               'personLabel': 'Cristina García Banegas'},
#              {'birthDate': '1938-12-17T00:00:00Z',
#               'person': 'http://www.wikidata.org/entity/Q3427172',
#               'personLabel': 'Renée Pietrafesa Bonnet'}],
#  'Uzbekistan': [{'birthDate': '1936-05-01T00:00:00Z',
#                  'person': 'http://www.wikidata.org/entity/Q4054642',
#                  'personLabel': 'Dilbar Abdurahmonova'}],
#  'Venezuela': [{'birthDate': '1853-12-22T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q241494',
#                 'personLabel': 'Teresa Carreño'},
#                {'birthDate': '1966-07-13T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q274583',
#                 'personLabel': 'Natalia Luis-Bassa'},
#                {'birthDate': '1986-07-08T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q454131',
#                 'personLabel': 'Victoria Sánchez'},
#                {'birthDate': '1917-01-05T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q2286704',
#                 'personLabel': 'Silvia Eisenstein'},
#                {'birthDate': '1932-05-20T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q1972696',
#                 'personLabel': 'Nazyl Báez Finol'},
#                {'birthDate': '1967-12-16T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q4750439',
#                 'personLabel': 'Ana María Raga'},
#                {'birthDate': '1953-01-01T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q4951274',
#                 'personLabel': 'María Guinand'},
#                {'birthDate': '1955-09-25T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q5043483',
#                 'personLabel': 'Carmen Helena Téllez'},
#                {'birthDate': '1957-04-26T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q29263372',
#                 'personLabel': 'Rosa Briceño Ortiz'},
#                {'birthDate': '1978-06-26T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q51883477',
#                 'personLabel': 'Moicelí Medina'},
#                {'birthDate': '1967-12-16T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q4750439',
#                 'personLabel': 'Ana María Raga'},
#                {'birthDate': '1953-01-01T00:00:00Z',
#                 'person': 'http://www.wikidata.org/entity/Q4951274',
#                 'personLabel': 'María Guinand'}],
#  'Wales': [{'birthDate': '1861-04-07T00:00:00Z',
#             'person': 'http://www.wikidata.org/entity/Q5126032',
#             'personLabel': 'Clara Novello Davies'},
#            {'birthDate': '1928-06-02T00:00:00Z',
#             'person': 'http://www.wikidata.org/entity/Q41019354',
#             'personLabel': 'Gino Basille'},
#            {'birthDate': '1861-04-07T00:00:00Z',
#             'person': 'http://www.wikidata.org/entity/Q5126032',
#             'personLabel': 'Clara Novello Davies'}],
#  "West Ukrainian People's Republic": [{'birthDate': '1902-01-02T00:00:00Z',
#                                        'person': 'http://www.wikidata.org/entity/Q86972819',
#                                        'personLabel': 'Q86972819'}],
#  'Yugoslavia': [{'birthDate': '1893-08-20T00:00:00Z',
#                  'person': 'http://www.wikidata.org/entity/Q12786414',
#                  'personLabel': 'Breda Šček'}]}

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Read the data from the JSON file
with open('data.json', 'r') as f:
    data = json.load(f)

# Count the number of women orchestra chefs per country
counts = {country: len(chefs) for country, chefs in data.items()}

# Create a bar chart
sns.barplot(x=list(counts.keys()), y=list(counts.values()))
plt.xlabel('Country')
plt.ylabel('Number of women orchestra chefs')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 import plotly.graph_objects as go
#       3 # Read the data from the JSON file
#       4 with open('data.json', 'r') as f:
#
# ModuleNotFoundError: No module named 'plotly'
